# %%
from matlab_jarvis_files import get_jarvis_errors

# %%
path_GroundTruth = '/Volumes/fsmresfiles/Basic_Sciences/Phys/L_MillerLab/limblab/User_folders/Aajan/Jarvis_results/points_GroundTruth.csv'
path_HybridNetPredictions = '/Volumes/fsmresfiles/Basic_Sciences/Phys/L_MillerLab/limblab/User_folders/Aajan/Jarvis_results/points_HybridNet.csv'
med_errs = get_jarvis_errors.plot_jarvis_errors(path_GroundTruth, path_HybridNetPredictions)

# %%
med_errs, med_errs.shape
# Out:
# (array([19.02421945, 13.0879171 , 13.37929683, 13.94663464, 18.97638483,
#         13.90194906,  9.6052293 ,  8.69262735, 18.92229966,  9.31341703,
#         10.1087252 ,  9.99674858, 19.88722001, 14.6569956 , 11.44944892,
#         10.52581699, 19.27149173, 10.49873994, 13.40146372, 25.89679628,
#         18.7807272 , 59.70657047, 44.96120998]),
#  (23,))

# %%
from matlab_jarvis_files import plot_linklengths as pl

# %%
linklengths = pl.get_linklengths('/Volumes/fsmresfiles/Basic_Sciences/Phys/L_MillerLab/limblab/User_folders/Aajan/Jarvis_results/data3D_20210712.csv')

# %%
pl.plot_linklengths(linklengths,'20220512', bins = 400)
