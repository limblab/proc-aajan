# %% [markdown]
# # Old Videos

# %%
import numpy as np
from scipy import stats
import joint_angles as ja

# %%
data_path = '/Volumes/L_MillerLab/limblab/User_folders/Aajan/Jarvis_results/Aajan-MonkeyHand-PretrainedWeights-20220512/Predictions_3D_20220513-163511/data3D.csv'
data = np.genfromtxt(data_path, delimiter=',')

# %%
data.shape
# Out:
# (36002, 69)

# %%
np.isnan(data)
# Out:
# array([[ True,  True,  True, ...,  True,  True,  True],
#        [ True,  True,  True, ...,  True,  True,  True],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
inds = []
for i in range(data.shape[0]):
    if np.isnan(data[i]).all():
        inds.append(i)

# %%
inds
# Out:
# [0,
#  1,
#  235,
#  238,
#  246,
#  247,
#  248,
#  252,
#  253,
#  255,
#  257,
#  34875,
#  34876,
#  34878,
#  34879,
#  34880,
#  34885]

# %%
len(inds)
# Out:
# 17

# %%
angles = ja.get_joint_angles('/Volumes/L_MillerLab/limblab/User_folders/Aajan/Jarvis_results/Aajan-MonkeyHand-PretrainedWeights-20220512/Predictions_3D_20220513-163511/data3D.csv')

# %%
angles.shape
# Out:
# (36002, 5, 3)

# %%
ja.plot_angles(angles, '20220522')

# %% [markdown]
# # Modified Videos

# %%
data_path = '/Volumes/L_MillerLab/limblab/User_folders/Aajan/Jarvis_results/Aajan-MonkeyHand-PretrainedWeights-20220512/Predictions_3D_20220609-125919/data3D.csv'
data = np.genfromtxt(data_path, delimiter=',')

# %%
data.shape
# Out:
# (18549, 69)

# %%
angles = ja.get_joint_angles('/Volumes/L_MillerLab/limblab/User_folders/Aajan/Jarvis_results/Aajan-MonkeyHand-PretrainedWeights-20220512/Predictions_3D_20220609-125919/data3D.csv')

# %%
angles.shape
# Out:
# (18549, 5, 3)

# %%
ja.plot_angles(angles, '20220522')
