# %% [markdown]
# Link to more in-depth descriptions here: https://blackrockneurotech.com/research/wp-content/ifu/LB-0023-7.00_NEV_File_Format.pdf
#
# **Nev obj structure**
#
# It has three main attributes/functions: basic_header, getdata(), extended_headers. The documentation mentions others, such as processroicommments(), but the files we have do not have those.
#
# nevobj.basic_header returns a dictionary with the following keys/values:
# - **key**: 'FileTypeID', **value**: str (e.g. 'NEURALEV')
# - **key**: 'FileSpec', **value**: str with float (e.g. '2.3')
# - **key**: 'AddFlags', **value**: int (likely bool 1/0)
# - **key**: 'BytesInHeader', **value**: int
# - **key**: 'BytesInDataPackets', **value**: int
# - **key**: 'TimeStampResolution', **value**: int
# - **key**: 'SampleTimeResolution', **value**: int
# - **key**: 'TimeOrigin', **value**: datetime.datetime
# - **key**: 'CreatingApplication', **value**: str (e.g. 'File Dialog v7.0.4')
# - **key**: 'Comment', **value**: str
# - **key**: 'NumExtendedHeaders', **value**: int
#
# nevobj.getdata() takes a long time and returns a dictionary with the following structure:
# - **key**: spike_events, **value**: dict
#     - **key**: TimeStamps, **value**: list
#         - A list of times (integers) in ascending order at which spikes occur (**note**: this is NOT the same as the total duration of the session)
#         - The length of this list should, in theory, equal the number of spikes (aka threshold crossings)
#     - **key**: Unit, **value**: list
#         - A list whose length is equal to Timestamps. In all files I've opened, this list contains only 0s
#     - **key**: Channel, **value**: list
#         - A list that contains the channel number that corresponds to the spike event time in TimeStamps
#         - If the first entry of Timestamps is 30 and the first entry of Channel is 2, that means that a spike occurred in channel 2 at time 30
#     - **key**: Waveforms, ****value****: array
#         - Array shape: num timestamps x num channels
#         - The columns of this array contain the activity of the corresponding channel
# - **key**: digital_events, **value**: dict (**note: not all files have digital_events - FR and Cage usually do not**)
#     - **key**: Timestamps, **value**: list
#         - Not the same timestamps as spike_events. Different lengths and values.
#     - **key**: InsertionReason, **value**: list
#         - A list whose length is equal to Timestamps. In all files I've opened, this list contains only 1s
#     - **key**: UnparsedData, **value**: list
#         - A list with integers that encode various task- and trial-related information. Details can be found here:  https://github.com/limblab/Behavior/blob/master/src/target/words.h
#
# nevobj.extended_headers returns a list of dicts; the number of dicts equals 'NumExtendedHeaders' in nevobj.basic_headers. 3 dicts in a row correspond to one electrode and contain the following info:
# - dict1
#     - **key**: 'PacketID':, **value**: str (e.g. 'NEUEVWAV')
#     - **key**: 'ElectrodeID':, **value**:  int
#     - **key**: 'PhysicalConnector':, **value**: int
#     - **key**: 'ConnectorPin':, **value**:  int,
#     - **key**: 'DigitizationFactor':, **value**:  int,
#     - **key**: 'EnergyThreshold':, **value**:  int,
#     - **key**: 'HighThreshold':, **value**:  int,
#     - **key**: 'LowThreshold':, **value**:  int,
#     - **key**: 'NumSortedUnits':, **value**:  int,
#     - **key**: 'BytesPerWaveform':, **value**:  int,
#     - **key**: 'SpikeWidthSamples':, **value**:  int,
#     - **key**: 'EmptyBytes':, **value**: bytes
# - dict2: electrode number
#     - **key**: PacketID:, **value**: str 'NEUEVLBL'
#     - **key**: ElectrodeID:, **value**: int (e.g. 1, should correspond to dict1)
#     - **key**: Label:, **value**: str (the actual electrode number - e.g. 'elec78')
#     - **key**: EmptyBytes:, **value**:  bytes (e.g. b'\x00\x00\x00\x00\x00\x00')
# - dict3: filter information (type, frequency)
#     - **key**: PacketID, **value**: str (e.g. 'NEUEVFLT')
#     - **key**: ElectrodeID, **value**: int (e.g. 1, should corresond to dicts 1,2)
#     - **key**: HighFreqCorner, **value**: str with float (e.g. '250.0 Hz')
#     - **key**: HighFreqOrder, **value**: int (e.g. 4),
#     - **key**: HighFreqType, **value**: str (e.g. 'butterworth')
#     - **key**: LowFreqCorner, **value**: str with float (e.g. '7500.0 Hz')
#     - **key**: LowFreqOrder, **value**: int (e.g. 3)
#     - **key**: LowFreqType, **value**: str (e.g. 'butterworth')
#     - **key**: EmptyBytes, **value**: bytes
#
# **Nsx obj structure**
#
# nsxobj.basic_header produces a dictionary with the following structure:
# - **key**: 'FileTypeID', **value**: str (e.g.  'NEURALCD')
# - **key**: 'FileSpec', **value**: str with float (e.g.  '2.3')
# - **key**: 'BytesInHeader', **value**: int (e.g.  8762)
# - **key**: 'Label', **value**: str representing a rate (e.g.  '2 kS/s')
# - **key**: 'Comment', **value**: str
# - **key**: 'Period', **value**: int (e.g.  15)
# - **key**: 'TimeStampResolution', **value**: int (e.g.  30000)
# - **key**: 'TimeOrigin', **value**:(e.g.  datetime.datetime(2023, 2, 14, 21, 41, 36, 14000))
# - **key**: 'ChannelCount', **value**: int (e.g.  128)
#
# nsxobj.getdata() takes a few seconds a dict with the following structure:
# - **key**: elec_ids, **value**: list
#     - List of electrode id's
# - **key**: start_time_s, **value**: float
#     - Usually 0.
# - **key**: data_time_s, **value**: str
#     - In all of the files I've opened, this string has been 'all'.
# - **key**: downsample, **value**: int
#     - Likely boolean - 1s or 0s. In all the files I've opened, it's been 1.
# - **key**: data, **value**: list
#     - A list containing a numpy array. This contains emg, force, and other data.
# - **key**: data_headers, **value**: list whose only element is a dict
#     - **key**: Timestamp, **value**: int (always 0 from what I've seen)
#     - **key**: NumDataPoints, **value**: int (with number of total data points - should equal time length of file times sampling rate)
# - **key**: ExtendedHeaderIndices, **value**: list
#     - A list containing the unique electrode ids - i.e. the length of this list equals the number of electrodes. Values usually between 1 - num electrodes.
#
# nsxobj.extended_headers produces a list of dicts, one for each electrode. The dicts contain the following info:
# - **key**: 'Type', **value**: str (e.g. 'CC')
# - **key**: 'ElectrodeID', **value**: int (e.g. 1)
# - **key**: 'ElectrodeLabel', **value**: str (e.g. 'elec109')
# - **key**: 'PhysicalConnector', **value**: int (e.g. 1)
# - **key**: 'ConnectorPin', **value**: int (e.g. 1)
# - **key**: 'MinDigitalValue', **value**: int (e.g. -32764)
# - **key**: 'MaxDigitalValue', **value**: int (e.g. 32764)
# - **key**: 'MinAnalogValue', **value**: int (e.g. -8191)
# - **key**: 'MaxAnalogValue', **value**: int (e.g. 8191)
# - **key**: 'Units', **value**: str (e.g. 'uV')
# - **key**: 'HighFreqCorner', **value**: str with float in hz (e.g. '0.3 Hz')
# - **key**: 'HighFreqOrder', **value**: int (e.g. 1)
# - **key**: 'HighFreqType', **value**: str (e.g. 'butterworth')
# - **key**: 'LowFreqCorner', **value**: str with float in hz (e.g. '250.0 Hz')
# - **key**: 'LowFreqOrder', **value**: int (e.g. 4)
# - **key**: 'LowFreqType', **value**: str (e.g. 'butterworth')

# %% [markdown]
# Force Files

# %% [markdown]
# - sessions_key - from sessions table
# - paper_key - ignore for now
# - filename
# - file_id - auto
# - **rec_system** - 'Cerebus'
# - sampling_rate - based on nsx file type
# - **force_quality** - leave for now
# - **force_notes** - leave for now
# - **force_labels - sometimes in nsx extended headers, but not always - seems to be only sometimes for FR files - e.g. NsxFileObj.extended_headers[hdr_idx]['ElectrodeLabel'] returns Force_x** - FR should not have forces, but...?

# %%
# !pwd
# Out:
# /Users/aajanquail/Desktop/Jupyter_Notebooks/Miller_Lab/proc-aajan/Database_Migration

# %%
# Import dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import os
from os import path, system
import sys
import glob
from scipy import signal
import matplotlib.pyplot as plt
import xml.etree.ElementTree as ET
import time
# from PyQt5.QtWidgets import QFileDialog

# brpylib is the module that contains functions/classes that allow us to open and extract data from .nev and .nsx files
# from Python_Utilities import brpylib
# from Python_Utilities import brMiscFxns
sys.path.insert(0, '/Users/aajanquail/Desktop/Jupyter_Notebooks/Miller_Lab/')
from Python_Utilities_Kev import brpylib

# %%
sampling_rate_dict = {'ns1': 500, 'ns2': 1000, 'ns3': 2000, 'ns4': 10000, 'ns5': 30000, 'ns6': 0}

# %%
cerebus_data_dict = {}
base_dir = '/Volumes/L_MillerLab/data/'
for monkey in sorted(os.listdir(base_dir)):
#     if monkey not in ['.DS_Store','archive','Backed_up_data', 'Behavior','chewie-delete','CompiledCOFiles','DeepLabCutVids','DLC_models','DPZ','FSMIT_DataRestore_03172021', 'Han_13B1_target','IMU','Jarvis','Jango_redo','Jango_target_redo','LoadCell','Mihili_12A3_target','OldCerebusTest','Rats','Rats_target','Test data','Thumbs.db']:
    if (monkey == 'Pancake_20K3') or (monkey == 'Pop_18E3'):
        print(monkey)
        cerebus_data_dict[monkey] = {}
        monkey_path = os.path.join(base_dir, monkey)
        x = [i for i in os.listdir(monkey_path) if 'cerebus' in i.lower()]
        if len(x) != 0:
            cerebus_path = os.path.join(monkey_path, x[0])
        else:
            cerebus_path = monkey_path
        print(cerebus_path)
        nev_list = glob.glob(f"{cerebus_path}/*/*.nev")
        nsx_list = glob.glob(f"{cerebus_path}/*/*.ns*")
        ccf_list = glob.glob(f"{cerebus_path}/*/*.ccf")
        print(len(nev_list), len(nsx_list), len(ccf_list))
        cerebus_data_dict[monkey]['nev_list'] = nev_list
        cerebus_data_dict[monkey]['nsx_list'] = nsx_list
        cerebus_data_dict[monkey]['ccf_list'] = ccf_list
# Out:
# Pancake_20K3
# /Volumes/L_MillerLab/data/Pancake_20K3/Cerebus_data
# 116 88 90
# Pop_18E3
# /Volumes/L_MillerLab/data/Pop_18E3/CerebusData
# 766 858 607

# %%
l3 = [i for i in cerebus_data_dict['Pancake_20K3']['nsx_list'] if i[-1] == '3']
l6 = [i for i in cerebus_data_dict['Pancake_20K3']['nsx_list'] if i[-1] == '6']

# %%
# 'TimeStampResolution'
for file in l3:
    nsxobj = brpylib.NsxFile(file)
    print(nsxobj.basic_header['Label'])
# Out:
# 20211214_Pancake__FR_001.ns3 opened
# 2 kS/s
#
# 20230214_Pancake_WM_002.ns3 opened
# 2 kS/s
#
# 20230214_Pancake_WM_001.ns3 opened
# 2 kS/s
#
# 20230214_Pancake_WM_003.ns3 opened
# 2 kS/s
#
# 20210828_Pancake__FR_.ns3 opened
# 2 kS/s
#
# 20220921_Pancake_WS_Pre_Con_01.ns3 opened
# 2 kS/s
#
# 20220921_Pancake_PG_Pre_Con_02.ns3 opened
# 2 kS/s
#
# 20220921_Pancake_PG_Post_Con_03.ns3 opened
# 2 kS/s
#
# 20220921_Pancake_WS_Post_Con_04.ns3 opened
# 2 kS/s
#
# 20220920_Pancake_FR_004.ns3 opened
# 2 kS/s
#
# 20220920_Pancake_FR_005.ns3 opened
# 2 kS/s
#
# 20220920_Pancake_FR_002.ns3 opened
# 2 kS/s
#
# 20220920_Pancake_FR_003.ns3 opened
# 2 kS/s
#
# 20220920_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220121_Pancake_PG_001.ns3 opened
# 2 kS/s
#
# 20220106_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220103_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220103_Pancake_FR_002.ns3 opened
# 2 kS/s
#
# 20210826_Pancake__FR_001.ns3 opened
# 2 kS/s
#
# 20221102_Pancke_PG_Post_Cyp_01.ns3 opened
# 2 kS/s
#
# 20221102_Pancke_PG_Pre_Cyp_01.ns3 opened
# 2 kS/s
#
# 20210917_Pancake_PG_001.ns3 opened
# 2 kS/s
#
# 20210917_Pancake_PG_002.ns3 opened
# 2 kS/s
#
# 20230216_Pancake_WM_002.ns3 opened
# 2 kS/s
#
# 20230216_Pancake_WM_001.ns3 opened
# 2 kS/s
#
# 20220917_Pancake_FR_005.ns3 opened
# 2 kS/s
#
# 20220917_Pancake_FR_003.ns3 opened
# 2 kS/s
#
# 20220917_Pancake_FR_004.ns3 opened
# 2 kS/s
#
# 20210823_Pancake20K2_PG_001.ns3 opened
# 2 kS/s
#
# 20210913_Pancake_PG_001.ns3 opened
# 2 kS/s
#
# 20220916_Pancake_PG_Pre_Cyp_02.ns3 opened
# 2 kS/s
#
# 20220916_Pancake_PG_Pre_Cyp_04.ns3 opened
# 2 kS/s
#
# 20220916_Pancake_WS_Post_Cyp_02.ns3 opened
# 2 kS/s
#
# 20220916_Pancake_PG_Pre_Cyp_03.ns3 opened
# 2 kS/s
#
# 20220916_Pancake_WS_Pre_Cyp_01.ns3 opened
# 2 kS/s
#
# 20220916_Pancake_PG_Post_Cyp_01.ns3 opened
# 2 kS/s
#
# 20221027_Pancake_PG_01.ns3 opened
# 2 kS/s
#
# 20210831_Pancake_KG_001.ns3 opened
# 2 kS/s
#
# 20220623_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220107_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220107_Pancake_FR_002.ns3 opened
# 2 kS/s
#
# 20220124_Pancake_PG_001.ns3 opened
# 2 kS/s
#
# 20220222_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220222_Pancake_FR_002.ns3 opened
# 2 kS/s
#
# 20221001_Pancake_EMGtest001.ns3 opened
# 2 kS/s
#
# 20220915_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220915_Pancake_FR_003.ns3 opened
# 2 kS/s
#
# 20220915_Pancake_FR_004.ns3 opened
# 2 kS/s
#
# 20220915_Pancake_FR_002.ns3 opened
# 2 kS/s
#
# 20210911_Pancake_PG_001.ns3 opened
# 2 kS/s
#
# 20210920_Pancake_KG_001.ns3 opened
# 2 kS/s
#
# 20210920_Pancake_KG_002.ns3 opened
# 2 kS/s
#
# 20221028_Pancake_PG_01.ns3 opened
# 2 kS/s
#
# 20211115_Pancake__FR_001.ns3 opened
# 2 kS/s
#
# 20220907_Pancake_PG_Post_Caff_04.ns3 opened
# 2 kS/s
#
# 20220907_Pancake_PG_Pre_Caff_01.ns3 opened
# 2 kS/s
#
# 20220907_Pancake_WS_Pre_Caff_02.ns3 opened
# 2 kS/s
#
# 20220907_Pancake_WS_Post_Caff_03.ns3 opened
# 2 kS/s
#
# 20220907_Pancake_PG_Post_Caff_05.ns3 opened
# 2 kS/s
#
# 20210821_Pancake_PG_002.ns3 opened
# 2 kS/s
#
# 20220104_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220628_Pancake_FR_002.ns3 opened
# 2 kS/s
#
# 20220628_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220628_Pancake_FR_005.ns3 opened
# 2 kS/s
#
# 20220628_Pancake_FR_004.ns3 opened
# 2 kS/s
#
# 20220628_Pancake_FR_003.ns3 opened
# 2 kS/s
#
# 20220729_Pancake_PG_Post_Tiz_02.ns3 opened
# 2 kS/s
#
# 20220729_Pancake_PG_Post_Tiz_01.ns3 opened
# 2 kS/s
#
# 20221024_Pancake_WIso_001.ns3 opened
# 2 kS/s
#
# 20221024_Pancake_WIso_002.ns3 opened
# 2 kS/s
#
# 20220114_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# Pancake_20220125_PG_001.ns3 opened
# 2 kS/s
#
# 20220913_Pancake_FR_001.ns3 opened
# 2 kS/s
#
# 20220913_Pancake_FR_002.ns3 opened
# 2 kS/s

# %%
# 'TimeStampResolution'
for file in l6:
    nsxobj = brpylib.NsxFile(file)
    print(nsxobj.basic_header['Label'])
# Out:
# 20220921_Pancake_PG_Pre_Con_02.ns6 opened
# raw
#
# 20220921_Pancake_PG_Post_Con_03.ns6 opened
# raw
#
# 20220921_Pancake_WS_Pre_Con_01.ns6 opened
# raw
#
# 20220921_Pancake_WS_Post_Con_04.ns6 opened
# raw
#
# 20221102_Pancke_PG_Post_Cyp_01.ns6 opened
# raw
#
# 20221102_Pancke_PG_Pre_Cyp_01.ns6 opened
# raw
#
# 20220916_Pancake_PG_Pre_Cyp_04.ns6 opened
# raw
#
# 20220916_Pancake_PG_Pre_Cyp_03.ns6 opened
# raw
#
# 20220916_Pancake_WS_Post_Cyp_02.ns6 opened
# raw
#
# 20220916_Pancake_PG_Pre_Cyp_02.ns6 opened
# raw
#
# 20220916_Pancake_PG_Post_Cyp_01.ns6 opened
# raw
#
# 20220916_Pancake_WS_Pre_Cyp_01.ns6 opened
# raw
#
# 20221027_Pancake_PG_01.ns6 opened
# raw
#
# 20221028_Pancake_PG_01.ns6 opened
# raw

# %% [markdown]
# # Remember to change code in brpylib.py to allow for large files > 1GB!!

# %%
force_dict = {'filename': [], 'rec_system': [], 'sampling_rate': [], 'force_labels': []}

for monkey in cerebus_data_dict.keys():
    for file in cerebus_data_dict[monkey]['nsx_list']:
        filename = file.split('/')[-1]
        if (('FR' not in filename) and ('freereaching' not in filename) and ('Cage' not in filename)):
            nsxobj = brpylib.NsxFile(file)
            output_nsx = nsxobj.getdata()
            if output_nsx == 0:
                continue
            force_labels_lst = []
            for plot_chan in output_nsx['elec_ids']:
                ch_idx  = output_nsx['elec_ids'].index(plot_chan)
                hdr_idx = output_nsx['ExtendedHeaderIndices'][ch_idx]
                label = nsxobj.extended_headers[hdr_idx]['ElectrodeLabel']
                force_labels_lst.append(label)
                force_labels_lst.append(',')
                
            force_dict['force_labels'].append(label)    
            force_dict['filename'].append(filename)
            force_dict['rec_system'].append('Cerebus')
            force_dict['sampling_rate'].append(sampling_rate_dict[filename[-3:]])
# Out:
# 20230214_Pancake_WM_002.ns3 opened
#
# 20230214_Pancake_WM_001.ns3 opened
#
# 20230214_Pancake_WM_003.ns3 opened
#
# 20220921_Pancake_WS_Pre_Con_01.ns3 opened
#
# 20220921_Pancake_PG_Pre_Con_02.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220921_Pancake_PG_Post_Con_03.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220921_Pancake_PG_Pre_Con_02.ns3 opened
#
# 20220921_Pancake_PG_Post_Con_03.ns3 opened
#
# 20220921_Pancake_WS_Pre_Con_01.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220921_Pancake_WS_Post_Con_04.ns3 opened
#
# 20220921_Pancake_WS_Post_Con_04.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220121_Pancake_PG_001.ns3 opened
#
# 20221102_Pancke_PG_Post_Cyp_01.ns3 opened
#
# 20221102_Pancke_PG_Pre_Cyp_01.ns3 opened
#
# 20221102_Pancke_PG_Post_Cyp_01.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20221102_Pancke_PG_Pre_Cyp_01.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20210917_Pancake_PG_001.ns3 opened
#
# 20210917_Pancake_PG_002.ns3 opened
#
# 20230216_Pancake_WM_002.ns3 opened
#
# 20230216_Pancake_WM_001.ns3 opened
#
# 20210823_Pancake20K2_PG_001.ns3 opened
#
# 20210913_Pancake_PG_001.ns3 opened
#
# 20220916_Pancake_PG_Pre_Cyp_04.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220916_Pancake_PG_Pre_Cyp_02.ns3 opened
#
# 20220916_Pancake_PG_Pre_Cyp_04.ns3 opened
#
# 20220916_Pancake_WS_Post_Cyp_02.ns3 opened
#
# 20220916_Pancake_PG_Pre_Cyp_03.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220916_Pancake_PG_Pre_Cyp_03.ns3 opened
#
# 20220916_Pancake_WS_Post_Cyp_02.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220916_Pancake_PG_Pre_Cyp_02.ns6 opened
#
# 20220916_Pancake_PG_Post_Cyp_01.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220916_Pancake_WS_Pre_Cyp_01.ns3 opened
#
# 20220916_Pancake_WS_Pre_Cyp_01.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220916_Pancake_PG_Post_Cyp_01.ns3 opened
#
# 20221027_Pancake_PG_01.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20221027_Pancake_PG_01.ns3 opened
#
# 20210831_Pancake_KG_001.ns3 opened
#
# 20220124_Pancake_PG_001.ns3 opened
#
# 20221001_Pancake_EMGtest001.ns3 opened
#
# 20210911_Pancake_PG_001.ns3 opened
#
# 20210920_Pancake_KG_001.ns3 opened
#
# 20210920_Pancake_KG_002.ns3 opened
#
# 20221028_Pancake_PG_01.ns3 opened
#
# 20221028_Pancake_PG_01.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220907_Pancake_PG_Post_Caff_04.ns3 opened
#
# 20220907_Pancake_PG_Pre_Caff_01.ns3 opened
#
# 20220907_Pancake_WS_Pre_Caff_02.ns3 opened
#
# 20220907_Pancake_WS_Post_Caff_03.ns3 opened
#
# 20220907_Pancake_PG_Post_Caff_05.ns3 opened
#
# 20210821_Pancake_PG_002.ns3 opened
#
# 20220729_Pancake_PG_Post_Tiz_02.ns3 opened
#
# 20220729_Pancake_PG_Post_Tiz_01.ns3 opened
#
# 20221024_Pancake_WIso_001.ns3 opened
#
# 20221024_Pancake_WIso_002.ns3 opened
#
# Pancake_20220125_PG_001.ns3 opened
#
# 20200309_Pop_WM_002.ns3 opened
#
# 20200309_Pop_WM_001.ns3 opened
#
# 20200309_Pop_WM_003.ns3 opened
#
# 20191021_Pop_horiz_WM_001.ns3 opened
#
# 20191021_Pop_horiz_WM_002.ns3 opened
#
# Pop_20200720_Key_002.ns3 opened
#
# Pop_20200720_PG_001.ns3 opened
#
# Pop_20210716_Treats_001.ns3 opened
#
# Pop_20210716_Key_001.ns3 opened
#
# Pop_20210716_PG_001.ns3 opened
#
# 20190724_Pop_freereaching_001.ns3 opened
#
# 20190724_Pop_freereaching_002.ns3 opened
#
# Pop_20200930_WM_chan29stim_50uA_009.ns5 opened
#
# Pop_20200930_WM_chan42stim_50uA_012_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_chan13stim_25uA_006.ns5 opened
#
# Pop_20200930__merged.ns1 opened
#
# Pop_20200930_WM_chan29stim_50uA_009.ns3 opened
#
# Pop_20200930_WM_chan42stim_25uA_011_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_chan13stim_25uA_006_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_stimHeadstage_001.ns3 opened
#
# Pop_20200930_WM_stimHeadstage_004_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_chan46stim_50uA_013_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_chan13stim_50uA_007_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_stimHeadstage_001.ns5 opened
# Output data requested is larger than 1 GB, skipping
#
# Pop_20200930_WM_stimHeadstage_005_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_chan29stim_25uA_010.ns5 opened
#
# Pop_20200930_WM_chan42stim_25uA_011.ns5 opened
#
# Pop_20200930_WM_chan46stim_25uA_014.ns5 opened
#
# Pop_20200930_WM_chan46stim_50uA_013.ns5 opened
#
# Pop_20200930_WM_stimHeadstage_005.ns5 opened
#
# Pop_20200930_WM_chan29stim_25uA_010.ns3 opened
#
# Pop_20200930_WM_chan13stim_50uA_007.ns3 opened
#
# Pop_20200930_WM_stimHeadstage_002.ns3 opened
#
# Pop_20200930_WM_chan13stim_25uA_006.ns3 opened
#
# Pop_20200930_WM_chan42stim_50uA_012.ns3 opened
#
# Pop_20200930_WM_stimHeadstage_004.ns5 opened
# Output data requested is larger than 1 GB, skipping
#
# Pop_20200930_WM_chan29stim_50uA_009_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_chan46stim_25uA_014_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_stimHeadstage_004.ns3 opened
#
# Pop_20200930_WM_chan46stim_50uA_013.ns3 opened
#
# Pop_20200930_WM_chan42stim_50uA_012.ns5 opened
#
# Pop_20200930_WM_chan42stim_25uA_011.ns3 opened
#
# Pop_20200930_WM_stimHeadstage_005.ns3 opened
#
# Pop_20200930_WM_chan13stim_50uA_007.ns5 opened
#
# Pop_20200930_WM_chan29stim_25uA_010_spikesExtracted.ns5 opened
#
# Pop_20200930_WM_stimHeadstage_002.ns5 opened
# Output data requested is larger than 1 GB, skipping
#
# Pop_20200930_WM_chan46stim_25uA_014.ns3 opened
#
# Pop_20200930_WM_stimHeadstage_001_spikesExtracted.ns5 opened
#
# 20200213_Pop_WM_001.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20200213_Pop_WM_002.ns3 opened
#
# 20200213_Pop_WM_001.ns3 opened
#
# 20200213_Pop_WM_002.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20190403_Pop_KG_002.ns3 opened
#
# 20190403_Pop_KG_001.ns3 opened
#
# Pop_20200819_PG_003.ns3 opened
#
# Pop_20200819_Key_002.ns3 opened
#
# Pop_20200819_PCG_001.ns3 opened
#
# Pop_20200731_Key_001.ns3 opened
#
# Pop_20200731_WM_004.ns3 opened
#
# Pop_20200731_WM_003.ns3 opened
#
# Pop_20200731_FreeReaching_005.ns3 opened
#
# Pop_20200731_PG_002.ns3 opened
#
# Pop_freeReach002.ns3 opened
#
# Pop_freeReach001.ns3 opened
#
# 20190910_Pop_horiz_wm_002.ns3 opened
#
# 20190910_Pop_horiz_wm_001.ns3 opened
#
# 20200226_Pop_MG_learning_001.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20200226_Pop_MG_learning_002.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20200226_Pop_MG_learning_001.ns3 opened
#
# 20200226_Pop_MG_learning_002.ns3 opened
#
# 20200212_Pop_freereach_.ns3 opened
#
# 20200212_Pop_freereach_2.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20200212_Pop_WM_.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20200212_Pop_WM_.ns3 opened
#
# 20200212_Pop_freereach_2.ns3 opened
#
# 20200212_Pop_freereach_.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20211020_Pop_PG_Pre_Cyp_02.ns3 opened
#
# 20211020_Pop_WS_Post_Cyp_03.ns3 opened
#
# 20211020_Pop_PG_Post_Cyp_04.ns3 opened
#
# 20211020_Pop_WS_Pre_Cyp_01.ns3 opened
#
# 20190503_Pop_wm_horiz_001.ns3 opened
#
# 20190503_Pop_wm_horiz_002.ns3 opened
#
# Pop_20210625_PG_001001.ns3 opened
#
# Pop_20210625_PG_002002.ns3 opened
#
# Pop_20201020_PCG_001001.ns3 opened
#
# Pop_20201020_PG_001001.ns3 opened
#
# Pop_20201020_PCG2_001001.ns3 opened
# Output data requested is larger than 1 GB, skipping
#
# 20191028_Pop_horizWM_001.ns3 opened
#
# 20191028_Pop_horizWM_002.ns3 opened
#
# 20190809_Pop_wm_002.ns3 opened
#
# 20190809_Pop_wm_001.ns3 opened
#
# 20190809_Pop_wm_003.ns3 opened
#
# 20190730_Pop_wm_002.ns3 opened
#
# 20190730_Pop_wm_001.ns3 opened
#
# 20190430_Pop_WM_horiz002.ns3 opened
#
# 20190430_Pop_WM_horiz001.ns3 opened
#
# 20200207_Pop_freeReaching_003.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20200207_Pop_WM_002.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20200207_Pop_WM_001.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20200207_Pop_freeReaching_003.ns3 opened
#
# 20200207_Pop_WM_002.ns3 opened
#
# 20200207_Pop_WM_001.ns3 opened
#
# 20220512_Pop_RT_IsoBox_001.ns2 opened
#
# 20220512_Pop_RT_IsoBox_002.ns2 opened
#
# 20220512_Pop_RT_IsoBox_001.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# 20220512_Pop_RT_IsoBox_002.ns6 opened
# Output data requested is larger than 1 GB, skipping
#
# Pop_20210908_Treats_001.ns3 opened
#
# Pop_20210908_MG_002.ns3 opened
#
# Pop_20210908_MG_001.ns3 opened
#
# 20190916_Pop_horiz_wm_002.ns3 opened
# 20190916_Pop_horiz_wm_001.ns3 opened
#
# Pop_20220322_PG_001.ns3 opened
#
# Pop_20220322_PG_002.ns3 opened
#
# 20190708_Pop_horizWM_001.ns3 opened
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       6 if (('FR' not in filename) and ('Cage' not in filename)):
#       7     nsxobj = brpylib.NsxFile(file)
# ----> 8     output_nsx = nsxobj.getdata()
#       9     if output_nsx == 0:
#      10         continue
#
# File ~/Desktop/Jupyter_Notebooks/Miller_Lab/Database_Migration/Python_Utilities_Kev/brpylib/brpylib.py:1251, in NsxFile.getdata(self, elec_ids, start_time_s, data_time_s, downsample, zeropad)
#    1249 data_length = output["data_headers"][x]["NumDataPoints"]
#    1250 recorded_data_bytes = data_length * num_elecs * DATA_BYTE_SIZE
# -> 1251 recorded_data = self.datafile.read(recorded_data_bytes)
#    1252 if zeropad is True:
#    1253     padsize = ceil(
#    1254         output["data_headers"][x]["Timestamp"] / self.basic_header["Period"]
#    1255     )
#
# KeyboardInterrupt:

# %%
elect_labels
# Out:
# {'FR': {'20211214_Pancake__FR_001.ns3': ['video_sync', 'Fx', 'Fy'],
#   '20210828_Pancake__FR_.ns3': ['video_sync'],
#   '20220920_Pancake_FR_004.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220920_Pancake_FR_005.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220920_Pancake_FR_002.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220920_Pancake_FR_003.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220920_Pancake_FR_001.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220106_Pancake_FR_001.ns3': ['video_sync'],
#   '20220103_Pancake_FR_001.ns3': ['video_sync'],
#   '20220103_Pancake_FR_002.ns3': ['video_sync'],
#   '20210826_Pancake__FR_001.ns3': ['video_sync'],
#   '20220917_Pancake_FR_005.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220917_Pancake_FR_003.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220917_Pancake_FR_004.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220623_Pancake_FR_001.ns3': ['video_sync'],
#   '20220107_Pancake_FR_001.ns3': ['video_sync'],
#   '20220107_Pancake_FR_002.ns3': ['video_sync'],
#   '20220222_Pancake_FR_001.ns3': ['video_sync'],
#   '20220222_Pancake_FR_002.ns3': ['video_sync'],
#   '20220915_Pancake_FR_001.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220915_Pancake_FR_003.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220915_Pancake_FR_004.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20220915_Pancake_FR_002.ns3': ['EMG_FCU1',
#    'EMG_FDP2',
#    'EMG_FDS2',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECR',
#    'video_sync'],
#   '20211115_Pancake__FR_001.ns3': ['video_sync'],
#   '20220104_Pancake_FR_001.ns3': ['video_sync'],
#   '20220628_Pancake_FR_002.ns3': ['video_sync'],
#   '20220628_Pancake_FR_001.ns3': ['video_sync'],
#   '20220628_Pancake_FR_005.ns3': ['video_sync'],
#   '20220628_Pancake_FR_004.ns3': ['video_sync'],
#   '20220628_Pancake_FR_003.ns3': ['video_sync'],
#   '20220114_Pancake_FR_001.ns3': ['video_sync'],
#   '20220913_Pancake_FR_001.ns3': ['video_sync'],
#   '20220913_Pancake_FR_002.ns3': ['video_sync']},
#  'Non FR': {'20230214_Pancake_WM_002.ns3': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28',
#    'elec111',
#    'elec98',
#    'elec99',
#    'elec87',
#    'elec86',
#    'elec75',
#    'elec74',
#    'elec63',
#    'elec62',
#    'elec51',
#    'elec50',
#    'elec39',
#    'elec38',
#    'elec27',
#    'elec26',
#    'elec16',
#    'elec25',
#    'elec7',
#    'elec15',
#    'elec6',
#    'elec14',
#    'elec5',
#    'elec13',
#    'elec4',
#    'elec12',
#    'elec3',
#    'elec11',
#    'elec2',
#    'elec10',
#    'elec1',
#    'elec9',
#    'elec8'],
#   '20230214_Pancake_WM_001.ns3': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28',
#    'elec111',
#    'elec98',
#    'elec99',
#    'elec87',
#    'elec86',
#    'elec75',
#    'elec74',
#    'elec63',
#    'elec62',
#    'elec51',
#    'elec50',
#    'elec39',
#    'elec38',
#    'elec27',
#    'elec26',
#    'elec16',
#    'elec25',
#    'elec7',
#    'elec15',
#    'elec6',
#    'elec14',
#    'elec5',
#    'elec13',
#    'elec4',
#    'elec12',
#    'elec3',
#    'elec11',
#    'elec2',
#    'elec10',
#    'elec1',
#    'elec9',
#    'elec8'],
#   '20230214_Pancake_WM_003.ns3': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28',
#    'elec111',
#    'elec98',
#    'elec99',
#    'elec87',
#    'elec86',
#    'elec75',
#    'elec74',
#    'elec63',
#    'elec62',
#    'elec51',
#    'elec50',
#    'elec39',
#    'elec38',
#    'elec27',
#    'elec26',
#    'elec16',
#    'elec25',
#    'elec7',
#    'elec15',
#    'elec6',
#    'elec14',
#    'elec5',
#    'elec13',
#    'elec4',
#    'elec12',
#    'elec3',
#    'elec11',
#    'elec2',
#    'elec10',
#    'elec1',
#    'elec9',
#    'elec8'],
#   '20220921_Pancake_WS_Pre_Con_01.ns3': ['Fx', 'Fy'],
#   '20220921_Pancake_PG_Pre_Con_02.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220921_Pancake_PG_Post_Con_03.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220921_Pancake_PG_Pre_Con_02.ns3': ['Fx', 'Fy'],
#   '20220921_Pancake_PG_Post_Con_03.ns3': ['Fx', 'Fy'],
#   '20220921_Pancake_WS_Pre_Con_01.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220921_Pancake_WS_Post_Con_04.ns3': ['Fx', 'Fy'],
#   '20220921_Pancake_WS_Post_Con_04.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220121_Pancake_PG_001.ns3': ['Fx', 'Fy'],
#   '20221102_Pancke_PG_Post_Cyp_01.ns3': ['Fx', 'Fy'],
#   '20221102_Pancke_PG_Pre_Cyp_01.ns3': ['Fx', 'Fy'],
#   '20221102_Pancke_PG_Post_Cyp_01.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20221102_Pancke_PG_Pre_Cyp_01.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20210917_Pancake_PG_001.ns3': ['Fx', 'Fy'],
#   '20210917_Pancake_PG_002.ns3': ['Fx', 'Fy'],
#   '20230216_Pancake_WM_002.ns3': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28',
#    'elec111',
#    'elec98',
#    'elec99',
#    'elec87',
#    'elec86',
#    'elec75',
#    'elec74',
#    'elec63',
#    'elec62',
#    'elec51',
#    'elec50',
#    'elec39',
#    'elec38',
#    'elec27',
#    'elec26',
#    'elec16',
#    'elec25',
#    'elec7',
#    'elec15',
#    'elec6',
#    'elec14',
#    'elec5',
#    'elec13',
#    'elec4',
#    'elec12',
#    'elec3',
#    'elec11',
#    'elec2',
#    'elec10',
#    'elec1',
#    'elec9',
#    'elec8'],
#   '20230216_Pancake_WM_001.ns3': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28',
#    'elec111',
#    'elec98',
#    'elec99',
#    'elec87',
#    'elec86',
#    'elec75',
#    'elec74',
#    'elec63',
#    'elec62',
#    'elec51',
#    'elec50',
#    'elec39',
#    'elec38',
#    'elec27',
#    'elec26',
#    'elec16',
#    'elec25',
#    'elec7',
#    'elec15',
#    'elec6',
#    'elec14',
#    'elec5',
#    'elec13',
#    'elec4',
#    'elec12',
#    'elec3',
#    'elec11',
#    'elec2',
#    'elec10',
#    'elec1',
#    'elec9',
#    'elec8'],
#   '20210823_Pancake20K2_PG_001.ns3': ['Fx', 'Fy'],
#   '20210913_Pancake_PG_001.ns3': ['Fx', 'Fy'],
#   '20220916_Pancake_PG_Pre_Cyp_04.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220916_Pancake_PG_Pre_Cyp_02.ns3': ['Fx', 'Fy'],
#   '20220916_Pancake_PG_Pre_Cyp_04.ns3': ['Fx', 'Fy'],
#   '20220916_Pancake_WS_Post_Cyp_02.ns3': ['Fx', 'Fy'],
#   '20220916_Pancake_PG_Pre_Cyp_03.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220916_Pancake_PG_Pre_Cyp_03.ns3': ['Fx', 'Fy'],
#   '20220916_Pancake_WS_Post_Cyp_02.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220916_Pancake_PG_Pre_Cyp_02.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220916_Pancake_PG_Post_Cyp_01.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220916_Pancake_WS_Pre_Cyp_01.ns3': ['Fx', 'Fy'],
#   '20220916_Pancake_WS_Pre_Cyp_01.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220916_Pancake_PG_Post_Cyp_01.ns3': ['Fx', 'Fy'],
#   '20221027_Pancake_PG_01.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20221027_Pancake_PG_01.ns3': ['Fx', 'Fy'],
#   '20210831_Pancake_KG_001.ns3': ['Fx', 'Fy'],
#   '20220124_Pancake_PG_001.ns3': ['Fx', 'Fy'],
#   '20221001_Pancake_EMGtest001.ns3': ['EMG_PT',
#    'EMG_APB',
#    'EMG_FPB',
#    'EMG_Lum',
#    'EMG_ECU',
#    'EMG_ECU/ECR',
#    'EMG_ECR',
#    'EMG_EDC1',
#    'EMG_EDC2',
#    'EMG_Tri',
#    'EMG_Bi',
#    'video_sync'],
#   '20210911_Pancake_PG_001.ns3': ['Fx', 'Fy'],
#   '20210920_Pancake_KG_001.ns3': ['Fx', 'Fy'],
#   '20210920_Pancake_KG_002.ns3': ['Fx', 'Fy'],
#   '20221028_Pancake_PG_01.ns3': ['Fx', 'Fy'],
#   '20221028_Pancake_PG_01.ns6': ['elec109',
#    'elec110',
#    'elec97',
#    'elec85',
#    'elec83',
#    'elec73',
#    'elec84',
#    'elec61',
#    'elec72',
#    'elec49',
#    'elec60',
#    'elec48',
#    'elec59',
#    'elec37',
#    'elec70',
#    'elec36',
#    'elec71',
#    'elec24',
#    'elec58',
#    'elec35',
#    'elec45',
#    'elec23',
#    'elec47',
#    'elec22',
#    'elec46',
#    'elec21',
#    'elec34',
#    'elec20',
#    'elec33',
#    'elec19',
#    'elec32',
#    'elec18',
#    'elec108',
#    'elec96',
#    'elec107',
#    'elec95',
#    'elec106',
#    'elec94',
#    'elec105',
#    'elec93',
#    'elec104',
#    'elec81',
#    'elec92',
#    'elec80',
#    'elec103',
#    'elec68',
#    'elec91',
#    'elec82',
#    'elec90',
#    'elec69',
#    'elec79',
#    'elec56',
#    'elec78',
#    'elec57',
#    'elec66',
#    'elec67',
#    'elec54',
#    'elec55',
#    'elec42',
#    'elec43',
#    'elec30',
#    'elec44',
#    'elec29',
#    'elec31',
#    'elec128',
#    'elec120',
#    'elec127',
#    'elec119',
#    'elec126',
#    'elec118',
#    'elec125',
#    'elec117',
#    'elec124',
#    'elec116',
#    'elec123',
#    'elec115',
#    'elec122',
#    'elec114',
#    'elec121',
#    'elec113',
#    'elec112',
#    'elec102',
#    'elec100',
#    'elec101',
#    'elec88',
#    'elec89',
#    'elec77',
#    'elec76',
#    'elec65',
#    'elec64',
#    'elec53',
#    'elec52',
#    'elec41',
#    'elec40',
#    'elec17',
#    'elec28'],
#   '20220907_Pancake_PG_Post_Caff_04.ns3': ['Fx', 'Fy'],
#   '20220907_Pancake_PG_Pre_Caff_01.ns3': ['Fx', 'Fy'],
#   '20220907_Pancake_WS_Pre_Caff_02.ns3': ['Fx', 'Fy'],
#   '20220907_Pancake_WS_Post_Caff_03.ns3': ['Fx', 'Fy'],
#   '20220907_Pancake_PG_Post_Caff_05.ns3': ['Fx', 'Fy'],
#   '20210821_Pancake_PG_002.ns3': ['Fx', 'Fy'],
#   '20220729_Pancake_PG_Post_Tiz_02.ns3': ['Fx', 'Fy'],
#   '20220729_Pancake_PG_Post_Tiz_01.ns3': ['Fx', 'Fy'],
#   '20221024_Pancake_WIso_001.ns3': ['Fx', 'Fy'],
#   '20221024_Pancake_WIso_002.ns3': ['Fx', 'Fy'],
#   'Pancake_20220125_PG_001.ns3': ['Fx', 'Fy']}}

# %%
for key in elect_labels['Non FR'].keys():
    if 'Fx' in elect_labels['Non FR'][key]:
        print(key, elect_labels['Non FR'][key])
# Out:
# 20220921_Pancake_WS_Pre_Con_01.ns3 ['Fx', 'Fy']
# 20220921_Pancake_PG_Pre_Con_02.ns3 ['Fx', 'Fy']
# 20220921_Pancake_PG_Post_Con_03.ns3 ['Fx', 'Fy']
# 20220921_Pancake_WS_Post_Con_04.ns3 ['Fx', 'Fy']
# 20220121_Pancake_PG_001.ns3 ['Fx', 'Fy']
# 20221102_Pancke_PG_Post_Cyp_01.ns3 ['Fx', 'Fy']
# 20221102_Pancke_PG_Pre_Cyp_01.ns3 ['Fx', 'Fy']
# 20210917_Pancake_PG_001.ns3 ['Fx', 'Fy']
# 20210917_Pancake_PG_002.ns3 ['Fx', 'Fy']
# 20210823_Pancake20K2_PG_001.ns3 ['Fx', 'Fy']
# 20210913_Pancake_PG_001.ns3 ['Fx', 'Fy']
# 20220916_Pancake_PG_Pre_Cyp_02.ns3 ['Fx', 'Fy']
# 20220916_Pancake_PG_Pre_Cyp_04.ns3 ['Fx', 'Fy']
# 20220916_Pancake_WS_Post_Cyp_02.ns3 ['Fx', 'Fy']
# 20220916_Pancake_PG_Pre_Cyp_03.ns3 ['Fx', 'Fy']
# 20220916_Pancake_WS_Pre_Cyp_01.ns3 ['Fx', 'Fy']
# 20220916_Pancake_PG_Post_Cyp_01.ns3 ['Fx', 'Fy']
# 20221027_Pancake_PG_01.ns3 ['Fx', 'Fy']
# 20210831_Pancake_KG_001.ns3 ['Fx', 'Fy']
# 20220124_Pancake_PG_001.ns3 ['Fx', 'Fy']
# 20210911_Pancake_PG_001.ns3 ['Fx', 'Fy']
# 20210920_Pancake_KG_001.ns3 ['Fx', 'Fy']
# 20210920_Pancake_KG_002.ns3 ['Fx', 'Fy']
# 20221028_Pancake_PG_01.ns3 ['Fx', 'Fy']
# 20220907_Pancake_PG_Post_Caff_04.ns3 ['Fx', 'Fy']
# 20220907_Pancake_PG_Pre_Caff_01.ns3 ['Fx', 'Fy']
# 20220907_Pancake_WS_Pre_Caff_02.ns3 ['Fx', 'Fy']
# 20220907_Pancake_WS_Post_Caff_03.ns3 ['Fx', 'Fy']
# 20220907_Pancake_PG_Post_Caff_05.ns3 ['Fx', 'Fy']
# 20210821_Pancake_PG_002.ns3 ['Fx', 'Fy']
# 20220729_Pancake_PG_Post_Tiz_02.ns3 ['Fx', 'Fy']
# 20220729_Pancake_PG_Post_Tiz_01.ns3 ['Fx', 'Fy']
# 20221024_Pancake_WIso_001.ns3 ['Fx', 'Fy']
# 20221024_Pancake_WIso_002.ns3 ['Fx', 'Fy']
# Pancake_20220125_PG_001.ns3 ['Fx', 'Fy']

# %%
sessions_key = []# - from sessions table
paper_key = []# ignore for now
filename = []#
file_id = []#auto
rec_system = []# 'Cerebus'
sampling_rate = []# based on nsx file type - what about rhd?
force_quality = []# leave for now
force_notes = []# leave for now
force_labels = []# sometimes in nsx extended headers, but not always - seems to be only sometimes for FR files - e.g. NsxFileObj.extended_headers[hdr_idx]['ElectrodeLabel'] returns Force_x - FR should not have forces, but...?

shortened_nev_list = [cerebus_data_dict['Pancake_20K3']['nev_list'][1]]
for nev_filename in shortened_nev_list:
    # open file
    print(nev_filename)
    nevobj = brpylib.NevFile(nev_filename)
    output = nevobj.getdata(elec_ids='all')
    
    fname = nev_filename.split('/')[-1][:-4]
    filename.append(fname)
    is_sorted.append(fname[-2:] == '-s')
    rec_system.append('Cerebus')
# Out:
# /Volumes/L_MillerLab/data/Pancake_20K3/Cerebus_data/20221103/20221103_Pancake_WI_001.nev
#
# 20221103_Pancake_WI_001.nev opened
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [41], in <cell line: 19>()
#      21 print(nev_filename)
#      22 nevobj = brpylib.NevFile(nev_filename)
# ---> 23 output = nevobj.getdata(elec_ids='all')
#      25 fname = nev_filename.split('/')[-1][:-4]
#      26 print(fname)
#
# File ~/Desktop/Jupyter_Notebooks/Miller_Lab/Database_Migration/Python_Utilities_Kev/brpylib/brpylib.py:978, in NevFile.getdata(self, elec_ids, wave_read)
#     972     output["PatientTrigger"] = {
#     973         "TimeStamps": list(ts[buttonPackets]),
#     974         "TriggerType": list(trigType[buttonPackets]),
#     975     }
#     977 # configuration packets
# --> 978 configPackets = [
#     979     idx
#     980     for idx, element in enumerate(PacketID)
#     981     if element == CONFIGURATION_PACKET_ID
#     982 ]
#     983 if len(configPackets) > 0:
#     984     changeType = np.ndarray(
#     985         (nPackets,),
#     986         "<H",
#    (...)
#     989         (self.basic_header["BytesInDataPackets"],),
#     990     )
#
# File ~/Desktop/Jupyter_Notebooks/Miller_Lab/Database_Migration/Python_Utilities_Kev/brpylib/brpylib.py:978, in <listcomp>(.0)
#     972     output["PatientTrigger"] = {
#     973         "TimeStamps": list(ts[buttonPackets]),
#     974         "TriggerType": list(trigType[buttonPackets]),
#     975     }
#     977 # configuration packets
# --> 978 configPackets = [
#     979     idx
#     980     for idx, element in enumerate(PacketID)
#     981     if element == CONFIGURATION_PACKET_ID
#     982 ]
#     983 if len(configPackets) > 0:
#     984     changeType = np.ndarray(
#     985         (nPackets,),
#     986         "<H",
#    (...)
#     989         (self.basic_header["BytesInDataPackets"],),
#     990     )
#
# KeyboardInterrupt:
