# %% [markdown]
# Link to more in-depth descriptions here: https://blackrockneurotech.com/research/wp-content/ifu/LB-0023-7.00_NEV_File_Format.pdf
#
# **Nev obj structure**
#
# It has three main attributes/functions: basic_header, getdata(), extended_headers. The documentation mentions others, such as processroicommments(), but the files we have do not have those.
#
# nevobj.basic_header returns a dictionary with the following keys/values:
# - **key**: 'FileTypeID', **value**: str (e.g. 'NEURALEV')
# - **key**: 'FileSpec', **value**: str with float (e.g. '2.3')
# - **key**: 'AddFlags', **value**: int (likely bool 1/0)
# - **key**: 'BytesInHeader', **value**: int
# - **key**: 'BytesInDataPackets', **value**: int
# - **key**: 'TimeStampResolution', **value**: int
# - **key**: 'SampleTimeResolution', **value**: int
# - **key**: 'TimeOrigin', **value**: datetime.datetime
# - **key**: 'CreatingApplication', **value**: str (e.g. 'File Dialog v7.0.4')
# - **key**: 'Comment', **value**: str
# - **key**: 'NumExtendedHeaders', **value**: int
#
# nevobj.getdata() takes a long time and returns a dictionary with the following structure:
# - **key**: spike_events, **value**: dict
#     - **key**: TimeStamps, **value**: list
#         - A list of times (integers) in ascending order at which spikes occur (**note**: this is NOT the same as the total duration of the session)
#         - The length of this list should, in theory, equal the number of spikes (aka threshold crossings)
#     - **key**: Unit, **value**: list
#         - A list whose length is equal to Timestamps. In all files I've opened, this list contains only 0s
#     - **key**: Channel, **value**: list
#         - A list that contains the channel number that corresponds to the spike event time in TimeStamps
#         - If the first entry of Timestamps is 30 and the first entry of Channel is 2, that means that a spike occurred in channel 2 at time 30
#     - **key**: Waveforms, ****value****: array
#         - Array shape: num timestamps x num channels
#         - The columns of this array contain the activity of the corresponding channel
# - **key**: digital_events, **value**: dict (**note: not all files have digital_events - FR and Cage usually do not**)
#     - **key**: Timestamps, **value**: list
#         - Not the same timestamps as spike_events. Different lengths and values.
#     - **key**: InsertionReason, **value**: list
#         - A list whose length is equal to Timestamps. In all files I've opened, this list contains only 1s
#     - **key**: UnparsedData, **value**: list
#         - A list with integers that encode various task- and trial-related information. Details can be found here:  https://github.com/limblab/Behavior/blob/master/src/target/words.h
#
# nevobj.extended_headers returns a list of dicts; the number of dicts equals 'NumExtendedHeaders' in nevobj.basic_headers. 3 dicts in a row correspond to one electrode and contain the following info:
# - dict1
#     - **key**: 'PacketID':, **value**: str (e.g. 'NEUEVWAV')
#     - **key**: 'ElectrodeID':, **value**:  int
#     - **key**: 'PhysicalConnector':, **value**: int
#     - **key**: 'ConnectorPin':, **value**:  int,
#     - **key**: 'DigitizationFactor':, **value**:  int,
#     - **key**: 'EnergyThreshold':, **value**:  int,
#     - **key**: 'HighThreshold':, **value**:  int,
#     - **key**: 'LowThreshold':, **value**:  int,
#     - **key**: 'NumSortedUnits':, **value**:  int,
#     - **key**: 'BytesPerWaveform':, **value**:  int,
#     - **key**: 'SpikeWidthSamples':, **value**:  int,
#     - **key**: 'EmptyBytes':, **value**: bytes
# - dict2: electrode number
#     - **key**: PacketID:, **value**: str 'NEUEVLBL'
#     - **key**: ElectrodeID:, **value**: int (e.g. 1, should correspond to dict1)
#     - **key**: Label:, **value**: str (the actual electrode number - e.g. 'elec78')
#     - **key**: EmptyBytes:, **value**:  bytes (e.g. b'\x00\x00\x00\x00\x00\x00')
# - dict3: filter information (type, frequency)
#     - **key**: PacketID, **value**: str (e.g. 'NEUEVFLT')
#     - **key**: ElectrodeID, **value**: int (e.g. 1, should corresond to dicts 1,2)
#     - **key**: HighFreqCorner, **value**: str with float (e.g. '250.0 Hz')
#     - **key**: HighFreqOrder, **value**: int (e.g. 4),
#     - **key**: HighFreqType, **value**: str (e.g. 'butterworth')
#     - **key**: LowFreqCorner, **value**: str with float (e.g. '7500.0 Hz')
#     - **key**: LowFreqOrder, **value**: int (e.g. 3)
#     - **key**: LowFreqType, **value**: str (e.g. 'butterworth')
#     - **key**: EmptyBytes, **value**: bytes
#
# **Nsx obj structure**
#
# nsxobj.basic_header produces a dictionary with the following structure:
# - **key**: 'FileTypeID', **value**: str (e.g.  'NEURALCD')
# - **key**: 'FileSpec', **value**: str with float (e.g.  '2.3')
# - **key**: 'BytesInHeader', **value**: int (e.g.  8762)
# - **key**: 'Label', **value**: str representing a rate (e.g.  '2 kS/s')
# - **key**: 'Comment', **value**: str
# - **key**: 'Period', **value**: int (e.g.  15)
# - **key**: 'TimeStampResolution', **value**: int (e.g.  30000)
# - **key**: 'TimeOrigin', **value**:(e.g.  datetime.datetime(2023, 2, 14, 21, 41, 36, 14000))
# - **key**: 'ChannelCount', **value**: int (e.g.  128)
#
# nsxobj.getdata() takes a few seconds a dict with the following structure:
# - **key**: elec_ids, **value**: list
#     - List of electrode id's
# - **key**: start_time_s, **value**: float
#     - Usually 0.
# - **key**: data_time_s, **value**: str
#     - In all of the files I've opened, this string has been 'all'.
# - **key**: downsample, **value**: int
#     - Likely boolean - 1s or 0s. In all the files I've opened, it's been 1.
# - **key**: data, **value**: list
#     - A list containing a numpy array. This contains emg, force, and other data.
# - **key**: data_headers, **value**: list whose only element is a dict
#     - **key**: Timestamp, **value**: int (always 0 from what I've seen)
#     - **key**: NumDataPoints, **value**: int (with number of total data points - should equal time length of file times sampling rate)
# - **key**: ExtendedHeaderIndices, **value**: list
#     - A list containing the unique electrode ids - i.e. the length of this list equals the number of electrodes. Values usually between 1 - num electrodes.
#
# nsxobj.extended_headers produces a list of dicts, one for each electrode. The dicts contain the following info:
# - **key**: 'Type', **value**: str (e.g. 'CC')
# - **key**: 'ElectrodeID', **value**: int (e.g. 1)
# - **key**: 'ElectrodeLabel', **value**: str (e.g. 'elec109')
# - **key**: 'PhysicalConnector', **value**: int (e.g. 1)
# - **key**: 'ConnectorPin', **value**: int (e.g. 1)
# - **key**: 'MinDigitalValue', **value**: int (e.g. -32764)
# - **key**: 'MaxDigitalValue', **value**: int (e.g. 32764)
# - **key**: 'MinAnalogValue', **value**: int (e.g. -8191)
# - **key**: 'MaxAnalogValue', **value**: int (e.g. 8191)
# - **key**: 'Units', **value**: str (e.g. 'uV')
# - **key**: 'HighFreqCorner', **value**: str with float in hz (e.g. '0.3 Hz')
# - **key**: 'HighFreqOrder', **value**: int (e.g. 1)
# - **key**: 'HighFreqType', **value**: str (e.g. 'butterworth')
# - **key**: 'LowFreqCorner', **value**: str with float in hz (e.g. '250.0 Hz')
# - **key**: 'LowFreqOrder', **value**: int (e.g. 4)
# - **key**: 'LowFreqType', **value**: str (e.g. 'butterworth')

# %% [markdown]
# Force Files

# %% [markdown]
# - sessions_key - from sessions table
# - paper_key - ignore for now
# - filename
# - file_id - auto
# - **rec_system** - 'Cerebus'
# - sampling_rate - based on nsx file type
# - **force_quality** - leave for now
# - **force_notes** - leave for now
# - **force_labels - sometimes in nsx extended headers, but not always - seems to be only sometimes for FR files - e.g. NsxFileObj.extended_headers[hdr_idx]['ElectrodeLabel'] returns Force_x** - FR should not have forces, but...?

# %%
# Import dependencies
import pandas as pd
import numpy as np
from sqlalchemy import create_engine
import os
from os import path, system
import sys
from sys import platform
import glob
# from PyQt5.QtWidgets import QFileDialog

# brpylib is the module that contains functions/classes that allow us to open and extract data from .nev and .nsx files
sys.path.insert(0, r'C:\Users\aqy3283\Desktop\proc-kevin')
from Blackrock_Python_Utilities import brpylib

# %%
sampling_rate_dict = {'ns1': 500, 'ns2': 1000, 'ns3': 2000, 'ns4': 10000, 'ns5': 30000, 'ns6': 30000}

# %%
sampling_rate_dict
# Out:
# {'ns1': 500,
#  'ns2': 1000,
#  'ns3': 2000,
#  'ns4': 10000,
#  'ns5': 30000,
#  'ns6': 30000}

# %%
cerebus_data_dict = {}
base_dir = 'Z:\data'
for monkey in sorted(os.listdir(base_dir)):
#     if monkey not in ['.DS_Store','archive','Backed_up_data', 'Behavior','chewie-delete','CompiledCOFiles','DeepLabCutVids','DLC_models','DPZ','FSMIT_DataRestore_03172021', 'Han_13B1_target','IMU','Jarvis','Jango_redo','Jango_target_redo','LoadCell','Mihili_12A3_target','OldCerebusTest','Rats','Rats_target','Test data','Thumbs.db']:
    if (monkey == 'Pancake_20K3') or (monkey == 'Pop_18E3'):
        print(monkey)
        cerebus_data_dict[monkey] = {}
        monkey_path = os.path.join(base_dir, monkey)
        x = [i for i in os.listdir(monkey_path) if 'cerebus' in i.lower()]
        if len(x) != 0:
            cerebus_path = os.path.join(monkey_path, x[0])
        else:
            cerebus_path = monkey_path
        print(cerebus_path)
        nev_list = glob.glob(f"{cerebus_path}\*\*.nev")
        nsx_list = glob.glob(f"{cerebus_path}\*\*.ns*")
        ccf_list = glob.glob(f"{cerebus_path}\*\*.ccf")
        print(len(nev_list), len(nsx_list), len(ccf_list))
        cerebus_data_dict[monkey]['nev_list'] = nev_list
        cerebus_data_dict[monkey]['nsx_list'] = nsx_list
        cerebus_data_dict[monkey]['ccf_list'] = ccf_list
# Out:
# Pancake_20K3
# Z:\data\Pancake_20K3\Cerebus_data
# 116 88 90
# Pop_18E3
# Z:\data\Pop_18E3\CerebusData
# 768 858 607

# %% [markdown]
# # Remember to change code in brpylib.py to allow for large files > 1GB!!

# %%
force_dict = {'filename': [], 'rec_system': [], 'sampling_rate': [], 'force_labels': []}

for monkey in cerebus_data_dict.keys():
    for file in cerebus_data_dict[monkey]['nsx_list']:
        filename = file.split('\\')[-1]
        if (('FR' not in filename) and ('free' not in filename.lower()) and ('cage' not in filename.lower())):
            nsxobj = brpylib.NsxFile(file)
            output_nsx = nsxobj.getdata()
            if output_nsx == 0:
                continue
            force_labels_lst = []
            for plot_chan in output_nsx['elec_ids']:
                ch_idx  = output_nsx['elec_ids'].index(plot_chan)
                hdr_idx = output_nsx['ExtendedHeaderIndices'][ch_idx]
                label = nsxobj.extended_headers[hdr_idx]['ElectrodeLabel']
                force_labels_lst.append(label)
                force_labels_lst.append(',')
            full_labels_str = ''.join(force_labels_lst)[:-1]
            force_dict['force_labels'].append(full_labels_str)    
            force_dict['filename'].append(filename)
            force_dict['rec_system'].append('Cerebus')
            force_dict['sampling_rate'].append(sampling_rate_dict[filename[-3:]])
# Out:
# Z:\data\Pancake_20K3\Cerebus_data\20210821\20210821_Pancake_PG_002.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20210823\20210823_Pancake20K2_PG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20210831\20210831_Pancake_KG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20210911\20210911_Pancake_PG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20210913\20210913_Pancake_PG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20210917\20210917_Pancake_PG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20210917\20210917_Pancake_PG_002.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20210920\20210920_Pancake_KG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20210920\20210920_Pancake_KG_002.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220121\20220121_Pancake_PG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220124\20220124_Pancake_PG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220125\Pancake_20220125_PG_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220729\20220729_Pancake_PG_Post_Tiz_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220729\20220729_Pancake_PG_Post_Tiz_02.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220907\20220907_Pancake_PG_Post_Caff_04.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220907\20220907_Pancake_PG_Post_Caff_05.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220907\20220907_Pancake_PG_Pre_Caff_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220907\20220907_Pancake_WS_Post_Caff_03.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220907\20220907_Pancake_WS_Pre_Caff_02.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_PG_Post_Cyp_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_PG_Post_Cyp_01.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_PG_Pre_Cyp_02.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_PG_Pre_Cyp_02.ns6 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_PG_Pre_Cyp_03.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_PG_Pre_Cyp_03.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_PG_Pre_Cyp_04.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_PG_Pre_Cyp_04.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_WS_Post_Cyp_02.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_WS_Post_Cyp_02.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_WS_Pre_Cyp_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220916\20220916_Pancake_WS_Pre_Cyp_01.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20220921\20220921_Pancake_PG_Post_Con_03.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220921\20220921_Pancake_PG_Post_Con_03.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20220921\20220921_Pancake_PG_Pre_Con_02.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220921\20220921_Pancake_PG_Pre_Con_02.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20220921\20220921_Pancake_WS_Post_Con_04.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220921\20220921_Pancake_WS_Post_Con_04.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20220921\20220921_Pancake_WS_Pre_Con_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20220921\20220921_Pancake_WS_Pre_Con_01.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20221001\20221001_Pancake_EMGtest001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20221024\20221024_Pancake_WIso_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20221024\20221024_Pancake_WIso_002.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20221027\20221027_Pancake_PG_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20221027\20221027_Pancake_PG_01.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20221028\20221028_Pancake_PG_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20221028\20221028_Pancake_PG_01.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20221102\20221102_Pancke_PG_Post_Cyp_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20221102\20221102_Pancke_PG_Post_Cyp_01.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20221102\20221102_Pancke_PG_Pre_Cyp_01.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20221102\20221102_Pancke_PG_Pre_Cyp_01.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pancake_20K3\Cerebus_data\20230214\20230214_Pancake_WM_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20230214\20230214_Pancake_WM_002.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20230214\20230214_Pancake_WM_003.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20230216\20230216_Pancake_WM_001.ns3 opened
#
# Z:\data\Pancake_20K3\Cerebus_data\20230216\20230216_Pancake_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190329\20190329_Pop__PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190403\20190403_Pop_KG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190403\20190403_Pop_KG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190409\20190409_Pop_PG_learning_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190423\20190423_Pop_key_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190424\20190424_Pop_key_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190424\20190424_Pop_key_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190429\20190429_Pop_wm_horiz_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190430\20190430_Pop_WM_horiz001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190430\20190430_Pop_WM_horiz002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190503\20190503_Pop_wm_horiz_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190503\20190503_Pop_wm_horiz_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190506\20190506_Pop_wm_horiz001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190506\20190506_Pop_wm_horiz002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190603\20190603_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190603\20190603_Pop_MG_key_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190604\20190604_Pop_MG_key_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190604\20190604_Pop_MG_key_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190604\20190604_Pop_MG_key_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190604\pop_20190604.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190605\20190605_Pop_horiz_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190605\20190605_Pop_horiz_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190605\20190605_Pop_horiz_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190606\20190606_Pop_horiz_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190606\20190606_Pop_horiz_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190606\20190606_Pop_horiz_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190607\20190607_Pop_horiz_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190607\20190607_Pop_horiz_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190607\20190607_Pop_horiz_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190607\20190607_Pop_horiz_WM_004.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190611\20190611_Pop_horiz_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190611\20190611_Pop_horiz_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190611\20190611_Pop_horiz_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190614\20190614_Pop_Horiz_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190614\20190614_Pop_Horiz_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190614\20190614_Pop_Horiz_WM_004.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190620\20190620_Pop_horiz_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190620\20190620_Pop_horiz_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190620\20190620_Pop_horiz_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190620\20190620_Pop_horiz_WM_004.ns3 opened
# Z:\data\Pop_18E3\CerebusData\20190620\20190620_Pop_horiz_WM_005.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190703\20190703_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190703\20190703_Pop_horizWM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190708\20190708_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190708\20190708_Pop_horizWM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190708\20190708_Pop_horizWM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190710\20190710_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190710\20190710_Pop_horizWM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190729\20190729_Pop_wm001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190730\20190730_Pop_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190730\20190730_Pop_wm_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190807\20190807_Pop_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190807\20190807_Pop_wm_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190808\20190808_Pop_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190808\20190808_Pop_wm_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190808\20190808_Pop_wm_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190809\20190809_Pop_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190809\20190809_Pop_wm_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190809\20190809_Pop_wm_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190903\20190903_Pop_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190906\20190906_Pop_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190906\20190906_Pop_wm_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20190909\20190909_Pop_horiz_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190909\20190909_Pop_horiz_wm_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20190909\20190909_Pop_horiz_wm_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190909\20190909_Pop_horiz_wm_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20190910\20190910_Pop_horiz_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190910\20190910_Pop_horiz_wm_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190913\20190913_Pop_horiz_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190913\20190913_Pop_horiz_wm_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190913\20190913_Pop_horiz_wm_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190916\20190916_Pop_horiz_wm_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20190916\20190916_Pop_horiz_wm_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191008\20191008_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191011\20191011_Pop_Horiz_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191011\20191011_Pop_Horiz_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191021\20191021_Pop_horiz_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191021\20191021_Pop_horiz_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191028\20191028_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191028\20191028_Pop_horizWM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191101\20191101_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191101\20191101_Pop_horizWM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191101\20191101_Pop_horizWM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191105\20191105_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191105\20191105_Pop_horizWM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191108\20191108_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191112\20191112_Pop_horizWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191112\20191112_Pop_horizWM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191120\20191120_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191120\20191120_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191122\20191122_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191122\20191122_Pop_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191122\20191122_Pop_WM_30k_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20191122\20191122_Pop_WM_30k_001.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20200205\20200205_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200205\20200205_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200206\20200206_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200207\20200207_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200207\20200207_Pop_WM_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200207\20200207_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200207\20200207_Pop_WM_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200210\2020210_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200210\2020210_Pop_WM_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200210\2020210_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200210\2020210_Pop_WM_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200210\2020210_Pop_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200210\2020210_Pop_WM_003.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200212\20200212_Pop_WM_.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200212\20200212_Pop_WM_.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200213\20200213_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200213\20200213_Pop_WM_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200213\20200213_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200213\20200213_Pop_WM_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200217\20200217_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200217\20200217_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200217\20200217_Pop_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200217\20200217_Pop_WM_003.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200220\20200220_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200220\20200220_Pop_WM_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200220\20200220_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200220\20200220_Pop_WM_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200224\20200224_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200224\20200224_Pop_WM_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200224\20200224_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200224\20200224_Pop_WM_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200226\20200226_Pop_MG_learning_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200226\20200226_Pop_MG_learning_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200226\20200226_Pop_MG_learning_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200226\20200226_Pop_MG_learning_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200227\20200227_Pop_MG_learning_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200227\20200227_Pop_MG_learning_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200227\20200227_Pop_MG_learning_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200227\20200227_Pop_MG_learning_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200228\20200228_PopWM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200228\20200228_PopWM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200309\20200309_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200309\20200309_Pop_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200309\20200309_Pop_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200310\Pop_20200310_WM_CO_001.ns3 opened
# Z:\data\Pop_18E3\CerebusData\20200310\Pop_20200310_WM_CO_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200310\Pop_20200310_WM_CO_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200310\Pop_20200310_WM_CO_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200310\Pop_20200310_WM_CO_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200310\Pop_20200310_WM_CO_003.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200311\Pop_20200311_WM_CO_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200311\Pop_20200311_WM_CO_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200316\Pop_20200316_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200316\Pop_20200316_WM_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200316\Pop_20200316_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200316\Pop_20200316_WM_003.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200617\Pop_20200617_WM_Horiz_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200617\Pop_20200617_WM_Horiz_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200626\Pop_20200626_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200629\Pop_20200629_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200629\Pop_20200629_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200714\Pop_20200714_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200717\Pop_20200717_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200720\Pop_20200720_Key_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200720\Pop_20200720_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200724\Pop_20200724_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200724\Pop_20200724_WM_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200727\Pop_20200727_Key_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200727\Pop_20200727_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200729\Pop_20200729_Key_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200729\Pop_20200729_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200731\Pop_20200731_Key_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200731\Pop_20200731_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200731\Pop_20200731_WM_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200731\Pop_20200731_WM_004.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200819\Pop_20200819_Key_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200819\Pop_20200819_PCG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200819\Pop_20200819_PG_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200821\20200821_Pop_PCG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200821\20200821_Pop_PG_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200821\20200821_Pop_WM_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200904\Pop_20200904_PCG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200904\Pop_20200904_WS_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200904\Pop_20200904_WS_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200925\Pop_20200925_WS_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan13stim_25uA_006.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan13stim_25uA_006.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan13stim_25uA_006_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan13stim_50uA_007.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan13stim_50uA_007.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan13stim_50uA_007_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan29stim_25uA_010.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan29stim_25uA_010.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan29stim_25uA_010_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan29stim_50uA_009.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan29stim_50uA_009.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan29stim_50uA_009_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan42stim_25uA_011.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan42stim_25uA_011.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan42stim_25uA_011_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan42stim_50uA_012.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan42stim_50uA_012.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan42stim_50uA_012_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan46stim_25uA_014.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan46stim_25uA_014.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan46stim_25uA_014_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan46stim_50uA_013.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan46stim_50uA_013.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_chan46stim_50uA_013_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_001.ns5 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_001_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_002.ns5 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_004.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_004.ns5 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_004_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_005.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_005.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930_WM_stimHeadstage_005_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20200930\Pop_20200930__merged.ns1 opened
#
# Z:\data\Pop_18E3\CerebusData\20201020\Pop_20201020_PCG2_001001.ns3 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20201020\Pop_20201020_PCG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201020\Pop_20201020_PG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan12and27stim_25uA_013.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan12and27stim_25uA_013.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan12and27stim_25uA_013_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan12stim_25uA_009.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan12stim_25uA_009.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan12stim_50uA_010.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan12stim_50uA_010.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan12stim_50uA_010_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan16stim_25uA_012.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan16stim_25uA_012.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan16stim_25uA_012_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan16stim_50uA_011.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan16stim_50uA_011.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan16stim_50uA_011_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan21stim_25uA_031.ns3 opened
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan21stim_25uA_031.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan21stim_25uA_031_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27and16stim_25uA_016.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27and16stim_25uA_016.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27and16stim_25uA_016_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27stim_25uA_014.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27stim_25uA_014.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27stim_25uA_014_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27stim_50uA_015.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27stim_50uA_015.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan27stim_50uA_015_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan29and21stim_25uA_028.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan29and21stim_25uA_028.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan29and21stim_25uA_028_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan29and21stim_25uA_029.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan29and21stim_25uA_029.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan29and21stim_25uA_029_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38and53stim_25uA_025.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38and53stim_25uA_025.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38and53stim_25uA_025_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38stim_25uA_017.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38stim_25uA_017.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38stim_25uA_017_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38stim_50uA_018.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38stim_50uA_018.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan38stim_50uA_018_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan53stim_25uA_020.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan53stim_25uA_020.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan53stim_25uA_020_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan53stim_50uA_019.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan53stim_50uA_019.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan53stim_50uA_019_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan56stim_25uA_021.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan56stim_25uA_021.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan56stim_25uA_021_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan56stim_50uA_022.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan56stim_50uA_022.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan56stim_50uA_022_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan62stim_25uA_024.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan62stim_25uA_024.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan62stim_25uA_024_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan62stim_50uA_023.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan62stim_50uA_023.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_chan62stim_50uA_023_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_001_spikesExtracted.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_001_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_002.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_002_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_003.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_003_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_004.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_004.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_004_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_005.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_005.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_005_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_006.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_006.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_006_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_007.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_007.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_008.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_008.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023_LeftM1_WM_EMG_task_008_spikesExtracted.ns5 opened
#
# Z:\data\Pop_18E3\CerebusData\20201023\Pop_20201023__merged.ns1 opened
#
# Z:\data\Pop_18E3\CerebusData\20201118\Pop_20201118_PCG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201118\Pop_20201118_PG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201118\Pop_20201118_WM_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201120\Pop_20201120_PCG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201120\Pop_20201120_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201120\Pop_20201120_WS_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201120\Pop_20201120_WS_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201125\Pop_20201125_PCG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201125\Pop_20201125_PG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201125\Pop_20201125_PG_002002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201125\Pop_20201125_WS_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201125\Pop_20201125_WS_002002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201128\Pop_20201128_PCG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20201128\Pop_20201128_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210430\20210430_Pop_PG_FlexorEMGs_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210505\20210505_Pop_PG_EMGonly_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210505\20210505_Pop_PG_EMGonly_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210526\20210526_Pop_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210526\20210526_Pop_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210601\20210601_Pop_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210601\20210601_Pop_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210601\20210601_Pop_PG_003.ns3 opened
# Z:\data\Pop_18E3\CerebusData\20210602\Pop_20210602_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210602\Pop_20210602_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210602\Pop_20210602_PG_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210609\Pop_20210609_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210609\Pop_20210609_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210610\20210610_Pop_WS_Post_Caff_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210610\20210610_Pop_WS_Post_Caff_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210610\20210610_Pop_WS_Post_Caff_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210610\20210610_Pop_WS_Pre_Caff_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210611\charging_circuit_noise.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210611\Pop_20210611_001.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210611\Pop_20210611_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20210611\Pop_20210611_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210611\Pop_20210611_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210611\Pop_20210611_PG_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210616\Pop_20210616_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210616\Pop_20210616_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210616\Pop_20210616_PG_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210617\20210617_Pop_PG_Post_Caff_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210617\20210617_Pop_PG_Pre_Caff_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210617\20210617_Pop_WS_Post_Caff_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210617\20210617_Pop_WS_Pre_Caff_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210617\Pop_20210617_BatteryNoise_test001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210617\Pop_20210617_BatteryNoise_test001.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210617\Pop_20210617_BatteryNoise_test002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210617\Pop_20210617_BatteryNoise_test002.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_4.5V.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_4V.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_5.5V.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_5V.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_6V.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_NoBattery001.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_Transmitter2.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_Transmitter2_4V.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_Transmitter2_5V.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_BatteryTest_Transmitter2_6V.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210618\Pop_20210618_PG_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210621\20210621_Pop_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210621\20210621_Pop_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210622\20210622_Pop_KG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210623\20210623_Pop_PG_Post_Cyp_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210623\20210623_Pop_PG_Pre_Cyp_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210623\20210623_Pop_WS_Post_Cyp_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210623\20210623_Pop_WS_Pre_Cyp_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210623\20210623_SteelCable_016154_6Volts001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210623\20210623_SteelCable_016154_6Volts001.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210623\20210623_SteelCable_016154_6Volts_PowerSupplyOff002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210623\20210623_SteelCable_016154_6Volts_PowerSupplyOff002.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210625\Pop_20210625_PG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210625\Pop_20210625_PG_002002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210630\Pop_20210630_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210702\Pop_20210702_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210709\Pop_20210709_Key_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210709\Pop_20210709_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210709\Pop_20210709_test_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210713\20210713_Pop_PG_Post_Con_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210713\20210713_Pop_PG_Post_Con_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210713\20210713_Pop_PG_Pre_Con_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210713\20210713_Pop_PG_Pre_Con_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_001.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_002.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_002.ns6 opened
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_003.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210715\20210715_Pop_MG_RTcomp_003.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20210716\Pop_20210716_Key_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210716\Pop_20210716_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210716\Pop_20210716_Treats_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210719\20210719_Pop_batteryTest_control_003.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210719\20210719_Pop_MG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210719\20210719_Pop_MG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210720\20210720_Pop_MG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210720\20210720_Pop_MG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210721\Pop_20210721_MG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210721\Pop_20210721_MG_002002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210721\Pop_20210721_Treats_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210722\20210722_Pop_PG_Post_Con_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210722\20210722_Pop_PG_Pre_Con_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210722\20210722_Pop_WS_Post_Con_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210722\20210722_Pop_WS_Pre_Con_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210722\MislabeledEMG_20210722_Pop_PG_Post_Con_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210722\MislabeledEMG_20210722_Pop_PG_Pre_Con_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210722\MislabeledEMG_20210722_Pop_WS_Post_Con_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210722\MislabeledEMG_20210722_Pop_WS_Pre_Con_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210723\Pop_20210723_MG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210723\Pop_20210723_MG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210723\Pop_20210723_Treats_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210730\Pop_20210730_MG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210730\Pop_20210730_MG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210730\Pop_20210730_Treats_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210806\Pop_20210806_MG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210806\Pop_20210806_Treats_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210806\Pop_20210806_Treats_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210813\20210813_Pop_PG_Post_Lex_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210813\20210813_Pop_PG_Pre_Lex_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210813\20210813_Pop_WS_Pre_Lex_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210813\MislabeledEMG_20210813_Pop_PG_Post_Lex_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210813\MislabeledEMG_20210813_Pop_WS_Post_Lex_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210902\20210902_Pop_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210902\20210902_Pop_04.ns3 opened
# Z:\data\Pop_18E3\CerebusData\20210902\20210902_Pop_PG_Post_Lex_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210902\20210902_Pop_PG_Pre_Lex_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210902\20210902_Pop_WS_Post_Lex_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210902\20210902_Pop_WS_Pre_Lex_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210908\Pop_20210908_MG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210908\Pop_20210908_MG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210908\Pop_20210908_Treats_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210917\20210917_Pop_PG_Post_Lex_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210917\20210917_Pop_PG_Pre_Lex_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210917\20210917_Pop_WS_Post_Lex_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210917\20210917_Pop_WS_Pre_Lex_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210922\20210922_Pop_PG_Post_Con_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210922\20210922_Pop_PG_Pre_Con_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210922\20210922_Pop_WS_Post_Con_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210922\20210922_Pop_WS_Pre_Con_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20210924\20210924_Pop_KG_001.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20210924\20210924_Pop_KG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211001\20211001_Pop_PG_Post_Cyp_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211001\20211001_Pop_PG_Pre_Cyp_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211001\20211001_Pop_WS_Post_Cyp_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211001\20211001_Pop_WS_Pre_Cyp_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211020\20211020_Pop_PG_Post_Cyp_04.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211020\20211020_Pop_PG_Pre_Cyp_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211020\20211020_Pop_WS_Post_Cyp_03.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211020\20211020_Pop_WS_Pre_Cyp_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211220\20211220_Pop_handle_WI_RT_001.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20211220\20211220_Pop_handle_WI_RT_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20211220\20211220_Pop_handle_WI_RT_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20220214\20220214_Pop_PG_Post_Con_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220214\20220214_Pop_PG_Pre_Con_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220304\20220304_Pop_PG_Post_Caff_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220304\20220304_Pop_PG_Pre_Caff_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220308\20220308_Pop_PG_Post_Caff_02.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220308\20220308_Pop_PG_Pre_Caff_01.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220312\Pop_20220312_PG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220312\Pop_20220312_PG_002002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220314\Pop_20220314_PG_001001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220314\Pop_20220314_PG_002002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220321\Pop_20220321_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220321\Pop_20220321_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220322\Pop_20220322_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220322\Pop_20220322_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220328\Pop_20220328_PG_001.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220328\Pop_20220328_PG_002.ns3 opened
#
# Z:\data\Pop_18E3\CerebusData\20220512\20220512_Pop_RT_IsoBox_001.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20220512\20220512_Pop_RT_IsoBox_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20220512\20220512_Pop_RT_IsoBox_002.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20220512\20220512_Pop_RT_IsoBox_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20220623\20220623_Pop_iso_001.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20220623\20220623_Pop_iso_001.ns6 opened
#
# Output data requested is larger than 1 GB, skipping
#
# Z:\data\Pop_18E3\CerebusData\20220623\20220623_Pop_iso_002.ns2 opened
#
# Z:\data\Pop_18E3\CerebusData\20220623\20220623_Pop_iso_002.ns6 opened
#
# Output data requested is larger than 1 GB, skipping

# %%
for key in force_dict.keys():
    print(len(force_dict[key]))
# Out:
# 483
# 483
# 483
# 483

# %%
df = pd.DataFrame(force_dict)

# %%
df.force_labels.unique()
# Out:
# array(['Fx,Fy',
#        'elec109,elec110,elec97,elec85,elec83,elec73,elec84,elec61,elec72,elec49,elec60,elec48,elec59,elec37,elec70,elec36,elec71,elec24,elec58,elec35,elec45,elec23,elec47,elec22,elec46,elec21,elec34,elec20,elec33,elec19,elec32,elec18,elec108,elec96,elec107,elec95,elec106,elec94,elec105,elec93,elec104,elec81,elec92,elec80,elec103,elec68,elec91,elec82,elec90,elec69,elec79,elec56,elec78,elec57,elec66,elec67,elec54,elec55,elec42,elec43,elec30,elec44,elec29,elec31,elec128,elec120,elec127,elec119,elec126,elec118,elec125,elec117,elec124,elec116,elec123,elec115,elec122,elec114,elec121,elec113,elec112,elec102,elec100,elec101,elec88,elec89,elec77,elec76,elec65,elec64,elec53,elec52,elec41,elec40,elec17,elec28',
#        'EMG_PT,EMG_APB,EMG_FPB,EMG_Lum,EMG_ECU,EMG_ECU/ECR,EMG_ECR,EMG_EDC1,EMG_EDC2,EMG_Tri,EMG_Bi,video_sync',
#        'elec109,elec110,elec97,elec85,elec83,elec73,elec84,elec61,elec72,elec49,elec60,elec48,elec59,elec37,elec70,elec36,elec71,elec24,elec58,elec35,elec45,elec23,elec47,elec22,elec46,elec21,elec34,elec20,elec33,elec19,elec32,elec18,elec108,elec96,elec107,elec95,elec106,elec94,elec105,elec93,elec104,elec81,elec92,elec80,elec103,elec68,elec91,elec82,elec90,elec69,elec79,elec56,elec78,elec57,elec66,elec67,elec54,elec55,elec42,elec43,elec30,elec44,elec29,elec31,elec128,elec120,elec127,elec119,elec126,elec118,elec125,elec117,elec124,elec116,elec123,elec115,elec122,elec114,elec121,elec113,elec112,elec102,elec100,elec101,elec88,elec89,elec77,elec76,elec65,elec64,elec53,elec52,elec41,elec40,elec17,elec28,elec111,elec98,elec99,elec87,elec86,elec75,elec74,elec63,elec62,elec51,elec50,elec39,elec38,elec27,elec26,elec16,elec25,elec7,elec15,elec6,elec14,elec5,elec13,elec4,elec12,elec3,elec11,elec2,elec10,elec1,elec9,elec8',
#        'Force_x,Force_y',
#        'EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FCR1,EMG_FDP1,EMG_FDS2,EMG_FDP3,EMG_APB,EMG_FPB,EMG_EDC3,EMG_ECU,EMG_ECR,Force_x,Force_y',
#        'EMG_FDP3,EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDP2,EMG_FDS2,EMG_1D1,EMG_PT,EMG_LUM,EMG_APB,EMG_FPB,Force_x,Force_y',
#        'EMG_3DI,EMG_EPL,EMG_SUP,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2,EMG_BI,EMG_TRI,EMG_LUM,EMG_APB,EMG_FPB,Force_x,Force_y',
#        'EMG_FDP3,EMG_FCU1,EMG_FDS1,EMG_ECU,EMG_FCR1,EMG_FDP2,EMG_ECR,EMG_1D1,EMG_PT,EMG_LUM,EMG_APB,EMG_FPB,Force_x,Force_y',
#        'EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDP2,EMG_1DI,EMG_LUM,EMG_APB,EMG_FPB,EMG_ECU,EMG_ECR,EMG_EDC1,Force_x,Force_y',
#        'EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDP2,EMG_1DI,EMG_LUM,EMG_APB,EMG_EPL,EMG_ECU,EMG_ECR,EMG_EDC1,X,Y',
#        'EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDP2,EMG_1DI,EMG_LUM,EMG_FPB,EMG_EPL,EMG_ECU,EMG_ECR,EMG_EDC1,X,Y',
#        'EMG_FDP3,EMG_PT,EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDP2,EMG_FDS2,EMG_1DI,EMG_Lum,EMG_APB,EMG_FPB',
#        'EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDP2,EMG_1DI,EMG_LUM,EMG_FPB,EMG_EPL,EMG_ECU,EMG_ECR,EMG_EDC1',
#        'elec78,elec88,elec68,elec58,elec56,elec48,elec57,elec38,elec47,elec28,elec37,elec27,elec36,elec18,elec45,elec17,elec46,elec8,elec35,elec16,elec24,elec7,elec26,elec6,elec25,elec5,elec15,elec4,elec14,elec3,elec13,elec2,elec77,elec67,elec76,elec66,elec75,elec65,elec74,elec64,elec73,elec54,elec63,elec53,elec72,elec43,elec62,elec55,elec61,elec44,elec52,elec33,elec51,elec34,elec41,elec42,elec31,elec32,elec21,elec22,elec11,elec23,elec10,elec12,elec96,elec87,elec95,elec86,elec94,elec85,elec93,elec84,elec92,elec83,elec91,elec82,elec90,elec81,elec89,elec80,elec79,elec71,elec69,elec70,elec59,elec60,elec50,elec49,elec40,elec39,elec30,elec29,elec19,elec20,elec1,elec9',
#        'EMG_FDP3,EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDS2,EMG_APB,EMG_FPB,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2,Force_X,Force_Y',
#        'EMG_FDP2,EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDS2,EMG_APB,EMG_FPB,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2,cameraSync',
#        'EMG_FDP2,EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_FDS2,EMG_APB,EMG_FPB,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2',
#        'EMG_FDP2,EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_1DI,EMG_APB,EMG_FPB,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2',
#        'EMG_FDP2,EMG_FCU1,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_1DI,EMG_APB,EMG_FPB,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2,cameraSync',
#        'EMG_FDP2,EMG_Lum,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_1DI,EMG_APB,EMG_FPB,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2',
#        'EMG_FDP2,EMG_Lum,EMG_FDS1,EMG_FDP1,EMG_FCR1,EMG_1DI,EMG_APB,EMG_FPB,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2,video_sync',
#        'video_sync',
#        'elec78,elec88,elec68,elec58,elec56,elec48,elec57,elec38,elec47,elec28,elec37,elec27,elec36,elec18,elec45,elec17,elec46,elec8,elec35,elec16,elec24,elec7,elec26,elec6,elec25,elec5,elec15,elec4,elec14,elec3,elec13,elec2,elec77,elec67,elec76,elec66,elec75,elec65,elec74,elec64,elec73,elec54,elec63,elec53,elec72,elec43,elec62,elec55,elec61,elec44,elec52,elec33,elec51,elec34,elec41,elec42,elec31,elec32,elec21,elec22,elec11,elec23,elec10,elec12,elec96,elec87,elec95,elec86,elec94,elec85,elec93,elec84,elec92,elec83,elec91,elec82,elec90,elec81,elec89,elec80,elec79,elec71,elec69,elec70,elec59,elec60,elec50,elec49,elec40,elec39,elec30,elec29,elec19,elec20,elec1,elec9,ainp15,ainp16',
#        'elec36,ainp16', 'elec14,ainp16', 'elec54,ainp16', 'elec43,ainp16',
#        'ainp15,ainp16', 'elecJOE', 'video_sync,Fx,Fy',
#        'elec78,elec88,elec68,elec58,elec56,elec48,elec57,elec38,elec47,elec28,elec37,elec27,elec36,elec18,elec45,elec17,elec46,elec8,elec35,elec16,elec24,elec7,elec26,elec6,elec25,elec5,elec15,elec4,elec14,elec3,elec13,elec2,elec77,elec67,elec76,elec66,elec75,elec65,elec74,elec64,elec73,elec54,elec63,elec53,elec72,elec43,elec62,elec55,elec61,elec44,elec52,elec33,elec51,elec34,elec41,elec42,elec31,elec32,elec21,elec22,elec11,elec23,elec10,elec12,elec82,elec81,elec80,elec71,elec69,elec70,elec59,elec60,elec50,elec49,elec40,elec39,elec30,elec29,elec19,elec20,elec1,elec9,stimsync',
#        'stimsync',
#        'elec78,elec88,elec68,elec58,elec56,elec48,elec57,elec38,elec47,elec28,elec37,elec27,elec36,elec18,elec45,elec17,elec46,elec8,elec35,elec16,elec24,elec7,elec26,elec6,elec25,elec5,elec15,elec4,elec14,elec3,elec13,elec2,elec77,elec67,elec76,elec66,elec75,elec65,elec74,elec64,elec73,elec54,elec63,elec53,elec72,elec43,elec62,elec55,elec61,elec44,elec52,elec33,elec51,elec34,elec41,elec42,elec31,elec32,elec21,elec22,elec11,elec23,elec10,elec12,elec96,elec87,elec95,elec86,elec94,elec85,elec93,elec84,elec92,elec83,elec91,elec82,elec90,elec81,elec89,elec80,elec79,elec71,elec69,elec70,elec59,elec60,elec50,elec49,elec40,elec39,elec30,elec29,elec19,elec20,elec1,elec9,stimsync',
#        'EMG_FCR1,EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FCR2,EMG_FDS1,EMG_FDS2,EMG_PT,EMG_APB,EMG_FPB,EMG_Lum,FX,FY',
#        'EMG_FCR1,EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FCR2,EMG_FDS1,EMG_FDS2,EMG_PT,EMG_Lum,EMG_FPB,EMG_APB,FX,FY',
#        'EMG_FCR1,EMG_FCR2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FDP2,EMG_FDS1,EMG_FDS2,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2,video_sync,Fx,Fy',
#        'elec27,elec26,elec25,elec9', 'elec36,elec35,elec34,elec9',
#        'EMG_FCR1,EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FCR2,EMG_FDS1,EMG_FDS2,EMG_PT,EMG_Lum,EMG_FPB,EMG_APB,F1,F2',
#        'Touchpad,Fx,Fy',
#        'EMG_FCR1,EMG_FCR2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FDP2,EMG_FDS1,EMG_FDS2,EMG_ECU,EMG_ECR,EMG_EDC1,EMG_EDC2',
#        'EMG_FCR1,EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FCR2,EMG_FDS1,EMG_FDS2,EMG_ECU,EMG_ECR,EMG_APB,EMG_EDC2,Fx,Fy',
#        'EMG_FCR1,EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FCR2,EMG_FDS1,EMG_FDS2,EMG_ECR,EMG_ECU,EMG_EDC1,EMG_EDC2,video_sync,Fx,Fy',
#        'EMG_FCR1,EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FDS2        ,EMG_FDS1,EMG_FCR2,EMG_ECR,EMG_ECU,EMG_EDC1,EMG_EDC2,video_sync,Fx,Fy',
#        'EMG_FCR1,EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FDP2,EMG_FDS1,EMG_FCR2,EMG_ECR,EMG_ECU,EMG_EDC1,EMG_EDC2,video_sync,Fx,Fy',
#        'EMG_FCR1,EMG_FDP2,EMG_FDP1,EMG_FDS1,Lum,EMG_FPB,EMG_APB,EMG_1DI,EMG_ECR,EMG_ECU,EMG_FCU2,EMG_FCR2',
#        'ainp13,Fx,Fy',
#        'EMG_FCR1,EMG_FDP2,EMG_FCU1,EMG_FCU2,EMG_FDP1,EMG_FCR2,EMG_FDS1,EMG_Lum,EMG_FPB_APB,EMG_APB,EMG_ECR,EMG_ECU',
#        'TP,Fx,Fy'], dtype=object)

# %%
df[df['force_labels'].str.contains('Fx|Fy|Force_x|Force_y')]
# Out:
#                             filename rec_system  sampling_rate    force_labels
# 0        20210821_Pancake_PG_002.ns3    Cerebus           2000           Fx,Fy
# 1    20210823_Pancake20K2_PG_001.ns3    Cerebus           2000           Fx,Fy
# 2        20210831_Pancake_KG_001.ns3    Cerebus           2000           Fx,Fy
# 3        20210911_Pancake_PG_001.ns3    Cerebus           2000           Fx,Fy
# 4        20210913_Pancake_PG_001.ns3    Cerebus           2000           Fx,Fy
# ..                               ...        ...            ...             ...
# 478          Pop_20220328_PG_002.ns3    Cerebus           2000    ainp13,Fx,Fy
# 479   20220512_Pop_RT_IsoBox_001.ns2    Cerebus           1000        TP,Fx,Fy
# 480   20220512_Pop_RT_IsoBox_002.ns2    Cerebus           1000        TP,Fx,Fy
# 481         20220623_Pop_iso_001.ns2    Cerebus           1000  Touchpad,Fx,Fy
# 482         20220623_Pop_iso_002.ns2    Cerebus           1000  Touchpad,Fx,Fy
#
# [238 rows x 4 columns]

# %%
df_filtered = df[df['force_labels'].str.contains('Fx|Fy|Force_x|Force_y')]

# %%
df_filtered['force_labels'] = 'Fx,Fy'
# Out:
# C:\Users\aqy3283\AppData\Local\Temp\ipykernel_65556\530678393.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtered['force_labels'] = 'Fx,Fy'

# %%
df_filtered.reset_index().drop('index', axis = 1)
# Out:
#                             filename rec_system  sampling_rate force_labels
# 0        20210821_Pancake_PG_002.ns3    Cerebus           2000        Fx,Fy
# 1    20210823_Pancake20K2_PG_001.ns3    Cerebus           2000        Fx,Fy
# 2        20210831_Pancake_KG_001.ns3    Cerebus           2000        Fx,Fy
# 3        20210911_Pancake_PG_001.ns3    Cerebus           2000        Fx,Fy
# 4        20210913_Pancake_PG_001.ns3    Cerebus           2000        Fx,Fy
# ..                               ...        ...            ...          ...
# 233          Pop_20220328_PG_002.ns3    Cerebus           2000        Fx,Fy
# 234   20220512_Pop_RT_IsoBox_001.ns2    Cerebus           1000        Fx,Fy
# 235   20220512_Pop_RT_IsoBox_002.ns2    Cerebus           1000        Fx,Fy
# 236         20220623_Pop_iso_001.ns2    Cerebus           1000        Fx,Fy
# 237         20220623_Pop_iso_002.ns2    Cerebus           1000        Fx,Fy
#
# [238 rows x 4 columns]

# %%
df_check_emgs = df[df['force_labels'].str.contains('elec', case = False)]

# %%
df_check_emgs
# Out:
#                                               filename rec_system
# 21                  20220916_Pancake_PG_Pre_Cyp_02.ns6    Cerebus  \
# 37                         20230214_Pancake_WM_001.ns3    Cerebus
# 38                         20230214_Pancake_WM_002.ns3    Cerebus
# 39                         20230214_Pancake_WM_003.ns3    Cerebus
# 40                         20230216_Pancake_WM_001.ns3    Cerebus
# ..                                                 ...        ...
# 367       Pop_20210618_BatteryTest_Transmitter2_5V.ns6    Cerebus
# 368       Pop_20210618_BatteryTest_Transmitter2_6V.ns6    Cerebus
# 380           20210623_SteelCable_016154_6Volts001.ns6    Cerebus
# 382  20210623_SteelCable_016154_6Volts_PowerSupplyO...    Cerebus
# 398                     20210715_Pop_MG_RTcomp_002.ns6    Cerebus
#
#      sampling_rate                                       force_labels
# 21           30000  elec109,elec110,elec97,elec85,elec83,elec73,el...
# 37            2000  elec109,elec110,elec97,elec85,elec83,elec73,el...
# 38            2000  elec109,elec110,elec97,elec85,elec83,elec73,el...
# 39            2000  elec109,elec110,elec97,elec85,elec83,elec73,el...
# 40            2000  elec109,elec110,elec97,elec85,elec83,elec73,el...
# ..             ...                                                ...
# 367          30000                         elec36,elec35,elec34,elec9
# 368          30000                         elec36,elec35,elec34,elec9
# 380          30000                         elec36,elec35,elec34,elec9
# 382          30000                         elec36,elec35,elec34,elec9
# 398          30000  elec78,elec88,elec68,elec58,elec56,elec48,elec...
#
# [70 rows x 4 columns]

# %%
file = cerebus_data_dict['Pancake_20K3']['nsx_list'][0]
nsxobj = brpylib.NsxFile(file)
output_nsx = nsxobj.getdata()
# Out:
# Z:\data\Pancake_20K3\Cerebus_data\20210821\20210821_Pancake_PG_002.ns3 opened

# %%
import matplotlib.pyplot as plt
for plot_chan in output_nsx['elec_ids']:

    ch_idx  = output_nsx['elec_ids'].index(plot_chan)
    print('Channel: '+str(plot_chan))
    hdr_idx = output_nsx['ExtendedHeaderIndices'][ch_idx]
    # Bug in the original code - changed np.arange(output_nsx['data'].shape[1] to np.arange(output_nsx['data'][0].shape[0]
    t       = output_nsx['start_time_s'] + np.arange(output_nsx['data'][0].shape[0]) / 2000#output_nsx['samp_per_s']

    plt.plot(t, output_nsx['data'][0][:,ch_idx])
#     plt.axis([t[0], t[-1], np.min(output_nsx['data'][0][:, ch_idx]), np.max(output_nsx['data'][0][:, ch_idx])])
    plt.locator_params(axis='y', nbins=20)
    plt.xlabel('Time (s)')
    plt.ylabel("Output (" + NsxFileObj.extended_headers[hdr_idx]['Units'] + ")")
    plt.title(NsxFileObj.extended_headers[hdr_idx]['ElectrodeLabel'])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 import matplotlib.pyplot as plt
#       2 for plot_chan in output_nsx['elec_ids']:
#       4     ch_idx  = output_nsx['elec_ids'].index(plot_chan)
#
# ModuleNotFoundError: No module named 'matplotlib'
